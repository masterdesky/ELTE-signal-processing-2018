# %% [markdown]
# # Signal processing course 2018/2019-1 @ ELTE
# # Assignment 3
# ## 10.08.2018

# %% [markdown]
# ## Task 1-2
#
# ### Low-pass filter (LPF) and the Bode plot
#
# A low-pass filter (LPF) is a filter that passes signals with a frequency lower than a selected cutoff frequency and attenuates signals with frequencies higher than the cutoff frequency. The exact frequency response of the filter depends on the filter design.[\[1\]](https://en.wikipedia.org/wiki/Low-pass_filter)
# We can construct a wingle pole LPF, simplest way as shown in the first picture:
#
# ![Low-pass filter](img\low-pass_filter_RC.svg "First order low-pass filter")
#
# This simple LPF circuit consists of a resistor in series with a load, and a capacitor in parallel with the load. The capacitor exhibits reactance, and blocks low-frequency signals, forcing them through the load instead. At higher frequencies the reactance drops, and the capacitor effectively functions as a short circuit. The combination of resistance and capacitance gives the time constant of the filter $\tau = RC$, where in SI, $R$ is measured in Ohms ($\Omega$) and $C$ is measured in Farads ($F$).[\[2\]](https://www.allaboutcircuits.com/textbook/direct-current/chpt-16/voltage-current-calculations/). The *break frequency*, also called the *turnover frequency* or *cutoff frequency* (in Hz), is determined by the time constant:
#
# $$
# f_{c} = \frac{1}{2 \pi} \omega_{c} = \frac{1}{2 \pi} \frac{1}{\tau} = \frac{1}{2 \pi} \frac{1}{RC}
# $$
#
# This circuit may be understood by considering the time the capacitor needs to charge or discharge through the resistor:
#
# * At low frequencies, there is plenty of time for the capacitor to charge up to practically the same voltage as the input voltage.
# * At high frequencies, the capacitor only has time to charge up a small amount before the input switches direction. The output goes up and down only a small fraction of the amount the input goes up and down. At double the frequency, there's only time for it to charge up half the amount.
#
# Another way to understand this circuit is through the concept of reactance at a particular frequency:
#
# * Since direct current (DC) cannot flow through the capacitor, DC input must flow out the path marked $V_{out}$ (analogous to removing the capacitor).
# * Since alternating current (AC) flows very well through the capacitor, almost as well as it flows through solid wire, AC input flows out through the capacitor, effectively short circuiting to ground (analogous to replacing the capacitor with just a wire).
#
# The capacitor is not an "on/off" object (like the block or pass fluidic explanation above). The capacitor variably acts between these two extremes. It is the *Bode plot* and frequency response that show this variability, which is as follows:
#
# ![Bode of LPF](img\lpf_bode.png "Bode plot of a first-order (one-pole) low-pass filter")
#
# The Bode plot for a linear, time-invariant system with transfer function $H(s)$ ($s$ being the complex frequency in the Laplace domain) consists of a magnitude plot and a phase plot.[\[3\]](https://en.wikipedia.org/wiki/Bode_plot)
#
# The *Bode magnitude plot* is the graph of the function $\left| H(s = j \omega) \right|$ of frequency $\omega$. The $\omega$-axis of the magnitude plot is logarithmic and the magnitude is given in decibels, i.e., a value for the magnitude $\left| H \right|$ is plotted on the axis at $20 \log_{10} \left| H \right|$.
#
# The *Bode phase plot* is the graph of the Argument (complex analysis)|phase, commonly expressed in degrees, of the transfer function $ \arg \left( H(s = j \omega) \right)$ as a function of $\omega$. The phase is plotted on the same logarithmic $\omega$-axis as the magnitude plot, but the value for the phase is plotted on a linear vertical axis.
#
#
# For a simple, single pole LPF, this could be calculated as follows[\[4\]](https://slideplayer.com/slide/4225151/):
#
# $$
# H \left(j \omega \right) = \frac{1}{1 + j \omega RC} = \frac{1}{1 + j \omega \tau} = \frac{1}{1 + j \tfrac{\omega}{w_{c}}}
# $$
#
# We need the absolute (real) values of this function, thus:
#
# $$
# Re \left( H \left(j \omega \right) \right) = \frac{1}{\sqrt{1 + \left( \tfrac{\omega}{w_{c}} \right)^{2}}}
# $$
#
# At the last step we convert this to decibels:
#
# $$
# Re \left( H \left(j \omega \right) \right)_{dB} = 20 \cdot \log_{10} Re \left( H \left(j \omega \right) \right) = 20 \cdot \log_{10} \left( \frac{1}{\sqrt{1 + \left( \tfrac{\omega}{w_{c}} \right)^{2}}} \right)
# $$
#
# ### Nyquist plot
#
# A Nyquist plot is a parametric plot of a frequency response used in signal processing. The most common use of Nyquist plots is for assessing the stability of a system with feedback. In Cartesian coordinates, the real part of the transfer function is plotted on the X axis. The imaginary part is plotted on the Y axis. The frequency is swept as a parameter, resulting in a plot per frequency.[\[5\]](https://en.wikipedia.org/wiki/Nyquist_stability_criterion)
# Summed, one can construct the Nyquist plot, using the transfer function $H \left(j \omega \right)$ plotting the following function:
#
# $$
# H_{Im} \left( H_{Re} \right)
# $$
#
# Where $H_{Re}$ is the argument of $H_{Im}$. It results in something, like the following plot:
#
# ![Nyquist of LPF](img\lpf_nyquist.png "Nyquist plot of a first-order (one-pole) low-pass filter")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cmath
from scipy import signal

# %%
sns.set(style='darkgrid')

# %% [markdown]
# ### Constructing transfer function

# %%
def TransferFunction(w_max, tau):
    
    # Sampling rate: 1000 Hz
    SampRate = w_max * 1000
    freqs = np.linspace(0, w_max, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal_pos = np.empty(SampRate, dtype=np.complex_)
    signal_neg = np.empty(SampRate, dtype=np.complex_)
    signal_bode = np.empty(SampRate)
    signal_arg = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):
        
        signal_pos[i] = (1/(1 + 1j * freqs[i] * tau))
        signal_neg[i] = (1/(1 + 1j * -freqs[i] * tau))

        signal_bode[i] = 20 * np.log10(signal_pos[i].real)
        signal_arg[i] = np.degrees(cmath.phase(signal_pos[i]))
        i += 1
    
    return(signal_pos, signal_neg, signal_bode, signal_arg, freqs)

# %%
# Resistance's magnitude in the low-pass filter
# Measured in Ohm (greek Omega)
LPF_R = 1e+5

# Capacitor's magnitude on the low-pass filter
# Measured Farads (F)
LPF_C = 1e-05

# Time constant for LPF with given characteristics
tau = LPF_R * LPF_C

# %%
# Maximal frequency
w_max = 10

signal_trans_pos, signal_trans_neg, signal_bode, signal_arg, freqs = TransferFunction(w_max, tau)

# %% [markdown]
# ### Bode diagram

# %%
fig_1_bode, axes_1_bode = plt.subplots(nrows=2, ncols = 1, figsize=(14,14))

axes_1_bode[0].set_title("Bode diagram of single pole LPF\nWith $\omega_{cut}$ = "+ str(1/tau) +" Hz\n", fontsize=17)

axes_1_bode[0].plot(freqs, signal_bode, c="red")
axes_1_bode[1].plot(freqs, signal_arg, c="red")

axes_1_bode[0].set_xscale("log")
axes_1_bode[1].set_xscale("log")

axes_1_bode[0].set_xlabel("Frequency (Hz)", fontsize=15)
axes_1_bode[0].set_ylabel("Magnitude (dB)", fontsize=15)

axes_1_bode[1].set_xlabel("Frequency (Hz)", fontsize=15)
axes_1_bode[1].set_ylabel("Phase (°)", fontsize=15)

plt.show()

# %% [markdown]
# ### Nyquist plot

# %%
fig_1_nyquist, axes_1_nyquist = plt.subplots(figsize=(14,7))

axes_1_nyquist.plot(signal_trans_pos.real, signal_trans_pos.imag, label="$\omega > 0$", c="red")
axes_1_nyquist.plot(signal_trans_neg.real, signal_trans_neg.imag, label="$\omega < 0$", c="green")

axes_1_nyquist.set_title("Nyquist diagram of single pole LPF\nWith $\omega_{cut}$ = "+ str(1/tau) +" Hz\n", fontsize=17)
axes_1_nyquist.set_xlabel("Re(H)", fontsize=17)
axes_1_nyquist.set_ylabel("Im(H)", fontsize=17)

plt.legend()
plt.show()

# %% [markdown]
# ### Filtering with LPF

# %% [markdown]
# #### Constructing low-pass filter with scipy

# %%
def LPF(t, tau, signal_in, order):
    
    # Sampling rate: 1000 Hz/seconds
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # Cut-off frequency of the filter
    w_cut = 1/tau
    
    # Normalize the frequency
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    w = w_cut / ((SampRate / t) / 2)
    
    # Calculate coefficients for low-pass Butterworth filter
    b, a = signal.butter(order, w, 'low')
    
    lpf_output = signal.lfilter(b, a, signal_in)
    
    return(time, lpf_output)

# %% [markdown]
# #### Constructing low-pass filter with transfer function
#
# $$
# \underbrace{Y \left (j \omega \right)}_{\text{Output signal in freq. dom.}} = \underbrace{H \left (j \omega \right)}_{\text{Transfer function}} \cdot \underbrace{X \left (j \omega \right)}_{\text{Input signal in freq. dom.}}
# $$

# %%
def LPF_Transfer(tau, input_signal_fft, freqs):
    
    # np.array to store the output signals's values
    output_signal_fft = np.empty(freqs.size, dtype=np.complex_)
    
    i = 0
    while(i < freqs.size):
        
        output_signal_fft[i] = (1/(1 + 1j * freqs[i] * tau)) * input_signal_fft[i]
        i += 1
        
    return output_signal_fft

# %% [markdown]
# #### Constructing high-pass filter

# %%
def HPF(t, tau, signal_in, order):
    
    # Sampling rate: 1000 Hz/seconds
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # Cut-off frequency of the filter
    w_cut = 1/tau
    
    # Normalize the frequency
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    w = w_cut / ((SampRate / t) / 2)
    
    # Calculate coefficients for low-pass Butterworth filter
    b, a = signal.butter(order, w, 'high')
    
    hpf_output = signal.lfilter(b, a, signal_in)
    
    return(time, hpf_output)

# %% [markdown]
# #### Calculate Fourier components for Fourier series

# %%
def FourierCoeff(signal, t, Complex=False):
    
    '''
    Parameters
    ----------
    signal : the periodic function's value as an np.array
    t: an np.linsapce array of points of time, where the signal got evalueted

    Returns
    -------
    if Complex == False, the function returns:

    a_0 : float
    a, b : np.float arrays describing respectively the cosine and sine coefficients

    =======
    if Complex == True, the function returns:

    c : 1-dimensional complex-valued np.array of size N+1
    '''

    # This function computes the one-dimensional n-point discrete Fourier Transform (DFT) 
    # of a real-valued array by means of an efficient algorithm called the Fast Fourier Transform (FFT)
    y = np.fft.rfft(signal) / t.size

    if(Complex):
        return(y)

    else:
        y *= 2
        return(y[0].real, y[1:-1].real, -y[1:-1].imag)

# %% [markdown]
# #### Reconstruct original function with coefficients of Fourier series
#
# ##### Real (a, b) coefficients

# %%
def FourierCalcReal(a_0, a, b, t, T, N_max):
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    ReconstTime = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array to store the reconstructed function's values
    ReconstFunc = np.empty(SampRate)
    
    # Calculate f(t) values by f(t) ~= a_0/2 + {Sum}_k=1->N (a_k*cos(2*pi*kt/T) + b_k*sin(2*pi*kt/T))
    for dt in range(0,len(ReconstTime)):
        ReconstFunc[dt] = a_0/2
        
        for k in range(1,N_max):
            ReconstFunc[dt] += a[k-1] * np.cos(2 * np.pi * k * ReconstTime[dt] / T) + b[k-1] * np.sin(2 * np.pi * k * ReconstTime[dt] / T)

    return(ReconstFunc, ReconstTime)

# %% [markdown]
# ##### Complex (c) coefficients

# %%
def FourierCalcComplex(c, t, N_max):
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    ReconstTime = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array to store the reconstructed function's values
    ReconstFunc = np.empty(SampRate, dtype=np.complex_)
    
    # Calculate f(t) values by f(t) ~= {Sum}_k=-N->N (c_k*e^(i*2*pi*kt/T))
    for dt in range(0,len(ReconstTime)):
        ReconstFunc[dt] = 0
        
        for k in range(0,N_max+1):
            ReconstFunc[dt] += c[k] * cmath.exp(1.0j * 2 * np.pi * k * ReconstTime[dt] / t)
        
        for k in range(1,N_max+1):
            ReconstFunc[dt] += np.conj(c[k]) * cmath.exp(1.0j * 2 * np.pi * (-k) * ReconstTime[dt] / t)

    return(ReconstFunc, ReconstTime)

# %% [markdown]
# #### Fast fourier transform (FFT)

# %%
def FFT(signal, t):
    
    y = np.fft.fft(signal)
    freqs = np.fft.fftfreq(signal.size, t/signal.size)
    
    return(y, freqs)

# %%
def IFFT(signal):
    
    y = np.fft.ifft(signal)
    
    return(y)

# %% [markdown]
# #### Function 1 - Square wave

# %%
def f_1(t, width, T):
    '''
    Input parameters:
    
    't': time in seconds
    'tau': bandwidth
    'T': period of signal
    '''
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):
        if((time[i] % T) < width):
            signal[i] = 1
            i += 1
        else:
            signal[i] = 0
            i += 1

    return(time, signal)

# %% [markdown]
# #### Square wave characteristics

# %%
# Order if filter
order_1 = 1

# length of signal in seconds
t_1 = 10

# Signal characteristics
width_1 = np.pi
T_1 = 2 * width_1

# %% [markdown]
# #### Going through LPF

# %%
time_1_lpf, signal_in_1_lpf = f_1(t_1, width_1, T_1)
lpf_time_1, lpf_output_1 = LPF(t_1, tau, signal_in_1_lpf, order_1)

# %%
fig_1_lpf, axes_1_lpf = plt.subplots(figsize=(14,7))

axes_1_lpf.plot(lpf_time_1, lpf_output_1, c="red", label="Filtered")
axes_1_lpf.plot(time_1_lpf, signal_in_1_lpf, c="green", label="Original")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
N_max_1_lpf = 40

c_1_lpf = FourierCoeff(lpf_output_1, lpf_time_1, Complex=True)
ReconstFunc_1_Comp_lpf, ReconstTime_1_Comp_lpf = FourierCalcComplex(c_1_lpf, t_1, N_max_1_lpf)

# %%
fig_f_1_Reconstruct_Complex_lpf, axes_f_1_Reconstruct_Complex_lpf = plt.subplots(figsize=(14,7))

axes_f_1_Reconstruct_Complex_lpf.plot(lpf_time_1, lpf_output_1, label="Original function", c="green")
axes_f_1_Reconstruct_Complex_lpf.plot(ReconstTime_1_Comp_lpf, ReconstFunc_1_Comp_lpf.real, label="Reconstructed function", c="red")

axes_f_1_Reconstruct_Complex_lpf.set_title(str(N_max_1_lpf) + "th harmonic of Fourier series")
axes_f_1_Reconstruct_Complex_lpf.set_xlabel("Time (s)")
axes_f_1_Reconstruct_Complex_lpf.set_ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# #### Going through HPF

# %%
time_1_hpf, signal_in_1_hpf = f_1(t_1, width_1, T_1)
hpf_time_1, hpf_output_1 = HPF(t_1, tau, signal_in_1_hpf, order_1)

# %%
fig_1_hpf, axes_1_hpf = plt.subplots(figsize=(14,7))

axes_1_hpf.plot(hpf_time_1, hpf_output_1, c="red", label="Filtered")
axes_1_hpf.plot(time_1_hpf, signal_in_1_hpf, c="green", label="Original")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
N_max_1_hpf = 50

c_1_hpf = FourierCoeff(hpf_output_1, hpf_time_1, Complex=True)
ReconstFunc_1_Comp_hpf, ReconstTime_1_Comp_hpf = FourierCalcComplex(c_1_hpf, t_1, N_max_1_hpf)

# %%
fig_f_1_Reconstruct_Complex_hpf, axes_f_1_Reconstruct_Complex_hpf = plt.subplots(figsize=(14,7))

axes_f_1_Reconstruct_Complex_hpf.plot(hpf_time_1, hpf_output_1, label="Original function", c="green")
axes_f_1_Reconstruct_Complex_hpf.plot(ReconstTime_1_Comp_hpf, ReconstFunc_1_Comp_hpf.real, label="Reconstructed function", c="red")

axes_f_1_Reconstruct_Complex_hpf.set_title(str(N_max_1_hpf) + "th harmonic of Fourier series")
axes_f_1_Reconstruct_Complex_hpf.set_xlabel("Time (s)")
axes_f_1_Reconstruct_Complex_hpf.set_ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# ### Constructing the output wave
#
# #### Fourier transform of square wave
#
# $$
# F(f(u)) = \int_{\infty}^{\infty} f(x) \cdot e^{-2 \pi i u x}\ dx = \int_{0}^{\tau} A \cdot e^{-2 \pi i u x}
# $$
#
# thus
#
# $$
# F(f(u)) = \frac{-A}{2 \pi i u} \left[e^{-2 \pi i u x} \right]_{0}^{X} = \frac{-A}{2 \pi i u} \left[ e^{-2 \pi i u x} - 1 \right] = \frac{+A}{2 \pi i u} \left[e^{- \pi i u x} - e^{\pi i u x} \right] \cdot e^{- \pi i u x}
# $$
#
# so
#
# $$
# F(u) = \frac{A}{\pi u} \cdot \sin \left( \pi u X \right) \cdot e^{- \pi i u X}
# $$
#
# finally taking its absolute value
#
# $$
# \left| F(f(u)) \right| = \left| \frac{AX}{\pi u X} \right| \cdot \left| \sin \left( \pi u X \right) \right| \cdot \left| e^{- \pi i u X} \right| = AX \cdot \frac{\sin \left( \pi u X \right)}{\pi u X} \approx \frac{\sin(x)}{x}
# $$
#
# The result is the $sinc$ function:
#
# ![Sinc function](img\sinc.png "The DFFT of a square wave")

# %% [markdown]
# #### Contstruct output signal with scipy.signal's Butterworth filter function

# %%
lpf_input_FFTd_1, lpf_in_freqs_FFTd_1 = FFT(signal_in_1_lpf, t_1)
lpf_output_FFTd_1, lpf_out_freqs_FFTd_1 = FFT(lpf_output_1, t_1)

lpf_output_IFFTd_1 = IFFT(lpf_output_FFTd_1)

# %%
fig_f_1_FFT_lpf, axes_f_1_FFT_lpf = plt.subplots(nrows=4, ncols=1, figsize=(14,28))

axes_f_1_FFT_lpf[0].plot(lpf_time_1, signal_in_1_lpf, c="green")
axes_f_1_FFT_lpf[1].plot(lpf_in_freqs_FFTd_1, lpf_input_FFTd_1.real, c="green")
axes_f_1_FFT_lpf[2].plot(lpf_out_freqs_FFTd_1, lpf_output_FFTd_1.real, c="red")
axes_f_1_FFT_lpf[3].plot(lpf_time_1, lpf_output_IFFTd_1.real, c="red")

axes_f_1_FFT_lpf[0].set_title("Input signal, time domain")
axes_f_1_FFT_lpf[0].set_xlabel("Time (s)")
axes_f_1_FFT_lpf[0].set_ylabel("Signal value in time domain")

axes_f_1_FFT_lpf[1].set_title("Fourier transform of input signal")
axes_f_1_FFT_lpf[1].set_xlabel("Frequency (Hz)")
axes_f_1_FFT_lpf[1].set_ylabel("Signal value in frequency domain")
axes_f_1_FFT_lpf[1].set_xscale("log")
#axes_f_1_FFT_lpf[1].set_yscale("log")
#axes_f_1_FFT_lpf[1].set_ylim(-100,100)

axes_f_1_FFT_lpf[2].set_title("Fourier transform of output signal")
axes_f_1_FFT_lpf[2].set_xlabel("Frequency (Hz)")
axes_f_1_FFT_lpf[2].set_ylabel("Signal value in frequency domain")
axes_f_1_FFT_lpf[2].set_xscale("log")
#axes_f_1_FFT_lpf[2].set_yscale("log")
#axes_f_1_FFT_lpf[2].set_ylim(-100,100)

axes_f_1_FFT_lpf[3].set_title("IFFT of input signal's FFT")
axes_f_1_FFT_lpf[3].set_xlabel("Time (s)")
axes_f_1_FFT_lpf[3].set_ylabel("Signal value")

plt.show()

# %% [markdown]
# #### Contstruct output signal with the input's FFT and the LPF's transfer function

# %%
lpf_output_FFTd_Transfer_1 = LPF_Transfer(tau, lpf_input_FFTd_1, lpf_in_freqs_FFTd_1)

# %%
lpf_output_IFFTd_Transfer_1 = IFFT(lpf_output_FFTd_Transfer_1)

# %%
fig_f_1_Transfer_lpf, axes_f_1_Transfer_lpf = plt.subplots(nrows=4, ncols=1, figsize=(14,28))

axes_f_1_Transfer_lpf[0].plot(lpf_time_1, signal_in_1_lpf, c="green")
axes_f_1_Transfer_lpf[1].plot(lpf_in_freqs_FFTd_1, lpf_input_FFTd_1.real, c="green")
axes_f_1_Transfer_lpf[2].plot(lpf_in_freqs_FFTd_1, lpf_output_FFTd_Transfer_1.real, c="red")
axes_f_1_Transfer_lpf[3].plot(lpf_time_1, lpf_output_IFFTd_Transfer_1.real, c="red")

axes_f_1_Transfer_lpf[0].set_title("Input signal, time domain")
axes_f_1_Transfer_lpf[0].set_xlabel("Time (s)")
axes_f_1_Transfer_lpf[0].set_ylabel("Signal value in time domain")

axes_f_1_Transfer_lpf[1].set_title("Fourier transform of input signal (Input of LPF)")
axes_f_1_Transfer_lpf[1].set_xlabel("Frequency (Hz)")
axes_f_1_Transfer_lpf[1].set_ylabel("Signal value in frequency domain")
axes_f_1_Transfer_lpf[1].set_xscale("log")
#axes_f_1_Transfer_lpf[1].set_yscale("log")
#axes_f_1_Transfer_lpf[1].set_ylim(-100,100)

axes_f_1_Transfer_lpf[2].set_title("Fourier transform of output signal (Output of LPF)")
axes_f_1_Transfer_lpf[2].set_xlabel("Frequency (Hz)")
axes_f_1_Transfer_lpf[2].set_ylabel("Signal value in frequency domain")
axes_f_1_Transfer_lpf[2].set_xscale("log")
#axes_f_1_Transfer_lpf[2].set_yscale("log")
#axes_f_1_Transfer_lpf[2].set_ylim(-100,100)

axes_f_1_Transfer_lpf[3].set_title("Reconstructed output signal")
axes_f_1_Transfer_lpf[3].set_xlabel("Time (s)")
axes_f_1_Transfer_lpf[3].set_ylabel("Signal value in time domain")

plt.show()

# %% [markdown]
# ### Some extra

# %% [markdown]
# #### Function 2 - Sawtooth wave

# %%
def f_2(t, h_max, T):
    '''
    Input parameters:
    
    't': time in seconds
    'h_max': maximum value of a 'tooth' 
    'T': period of signal
    '''
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):
        signal[i] = h_max * (time[i] % T) / T
        i += 1
        
    return(time, signal)

# %%
# Order if filter
order_2 = 1

# length of signal in seconds
t_2 = 10

h_max_2 = 1
T_2 = 2

time_2, signal_in_2 = f_2(t_2, h_max_2, T_2)
lpf_time_2, lpf_output_2 = LPF(t_2, tau, signal_in_2, order_2)

# %%
fig_2_lpf, axes_2_lpf = plt.subplots(figsize=(14,7))

axes_2_lpf.plot(time_2, signal_in_2, c="green", label="Original")
axes_2_lpf.plot(lpf_time_2, lpf_output_2, c="red", label="Filtered")

axes_2_lpf.set_title("Sawtooth signal, time domain")
axes_2_lpf.set_xlabel("Time (s)")
axes_2_lpf.set_ylabel("Signal value in time domain")

plt.legend()
plt.show()

# %% [markdown]
# #### Function 3

# %%
def f_3(t):
    '''
    Input parameter:
    
    't': time in seconds
    '''
    
    T = 2 * np.pi
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):

        if((t/SampRate * i) % T <= T/2):
            signal[i] = 2 * ((t/SampRate * i) % T)
            i += 1
            
        else:
            signal[i] = 2 * (T - ((t/SampRate * i) % T))
            i += 1
        
    return(time, signal)

# %%
# Order if filter
order_3 = 1

# length of signal in seconds
t_3 = 10

time_3, signal_in_3 = f_3(t_3)
lpf_time_3, lpf_output_3 = LPF(t_3, tau, signal_in_3, order_3)

# %%
fig_3_lpf, axes_3_lpf = plt.subplots(figsize=(14,7))

axes_3_lpf.plot(time_3, signal_in_3, c="green", label="Original")
axes_3_lpf.plot(lpf_time_3, lpf_output_3, c="red", label="Filtered")

axes_3_lpf.set_title("Triangle signal, time domain")
axes_3_lpf.set_xlabel("Time (s)")
axes_3_lpf.set_ylabel("Signal value in time domain")

plt.legend()
plt.show()

# %% [markdown]
# #### Function 4

# %%
def f_4(t):
    '''
    Input parameter:
    
    't': time in seconds
    '''
    
    T = 2 * np.pi
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):

        if(((t/SampRate * i) % T) <= T/2):
            signal[i] = np.pi**2 - ((t/SampRate * i) % T)**2
            i += 1
        else:
            signal[i] = np.pi**2 - (T - ((t/SampRate * i) % T))**2
            i += 1

    return(time, signal)

# %%
# Order if filter
order_4 = 1

# length of signal in seconds
t_4 = 10

time_4, signal_in_4 = f_4(t_4)
lpf_time_4, lpf_output_4 = LPF(t_4, tau, signal_in_4, order_4)

# %%
fig_4_lpf, axes_4_lpf = plt.subplots(figsize=(14,7))

axes_4_lpf.plot(time_4, signal_in_4, c="green", label="Original")
axes_4_lpf.plot(lpf_time_4, lpf_output_4, c="red", label="Filtered")

axes_4_lpf.set_title("Abs. sine signal, time domain")
axes_4_lpf.set_xlabel("Time (s)")
axes_4_lpf.set_ylabel("Signal value in time domain")

plt.legend()
plt.show()

# %% [markdown]
# ## Task 3
#
# ### Amplitude modulation of addition of $sin$ waves

# %%
def SineWave(t, T, A):
    
    T /= 2 * np.pi
    
    # Sampling rate: 1000 Hz/second
    SampRate = int(t * 1000)
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):
        
        signal[i] = np.sin(time[i] / T) * A
        i += 1

    return(time, signal)

# %%
def PositiveNegative():
    
    return -1 if np.random.rand() < 0.5 else 1


def RandomStep(t, SampRate):
    
    RandomStep = np.random.randint(1,10) / (SampRate/t) * PositiveNegative()
    
    return RandomStep


def ModulatorSignalRandom(t):
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)

    # np.array for containting values of current function
    signal = np.empty(SampRate)

    i = 1
    signal[0] = 0
    while(i < SampRate):

        signal[i] = signal[i - 1] + RandomStep(t, SampRate)
        i += 1

    return(time, signal)

# %%
t_sine = 100

sine_time_1, sine_signal_1 = SineWave(t_sine, T=2*np.pi, A=1)
sine_time_2, sine_signal_2 = SineWave(t_sine, T=np.pi, A=2)
sine_time_3, sine_signal_3 = SineWave(t_sine, T=np.pi, A=np.pi)
sine_time_4, sine_signal_4 = SineWave(t_sine, T=3, A=1.5)

sine_conv = sine_signal_1 + sine_signal_2 + sine_signal_3 + sine_signal_4

# %%
fig_sine, axes_sine = plt.subplots(figsize=(28,7))

axes_sine.plot(sine_time_1, sine_signal_1, c="red")
axes_sine.plot(sine_time_2, sine_signal_2, c="green")
axes_sine.plot(sine_time_3, sine_signal_3, c="blue")
axes_sine.plot(sine_time_4, sine_signal_4, c="orange")
axes_sine.plot(sine_time_4, sine_conv, '--', c="black")

axes_sine.set_xlabel("Time (s)")
axes_sine.set_ylabel("Signal value")

plt.show()

# %%
modulator_time, modulator_signal = ModulatorSignalRandom(t_sine)

norm_modulator_time, norm_modulator_signal = LPF(t_sine, tau, modulator_signal, order=1)

# %%
nrows = 6
ncols = 1
fig_sine_mod, axes_sine_mod = plt.subplots(nrows=nrows, ncols=ncols, figsize=(28,nrows*7))

axes_sine_mod[0].plot(modulator_time, modulator_signal, c="red")
axes_sine_mod[0].set_title("Modulator signal")
axes_sine_mod[0].set_xlabel("Time (s)")
axes_sine_mod[0].set_ylabel("Signal value")

axes_sine_mod[1].specgram(modulator_signal, NFFT=1024, Fs=1024, noverlap=512)

axes_sine_mod[2].plot(norm_modulator_time, norm_modulator_signal, c="red")
axes_sine_mod[2].set_title("Modulator signal (went to LPF)")
axes_sine_mod[2].set_xlabel("Time (s)")
axes_sine_mod[2].set_ylabel("Signal value")

axes_sine_mod[3].specgram(norm_modulator_signal, NFFT=1024, Fs=1024, noverlap=512)

axes_sine_mod[4].plot(sine_time_1, sine_signal_1, c="green")
axes_sine_mod[4].set_title("Original signal")
axes_sine_mod[4].set_xlabel("Time (s)")
axes_sine_mod[4].set_ylabel("Signal value")

axes_sine_mod[5].plot(sine_time_1, sine_signal_1, label="original signal", c="white")
axes_sine_mod[5].plot(norm_modulator_time, norm_modulator_signal, '--', label="modulator signal", c="red")
axes_sine_mod[5].plot(sine_time_1, sine_signal_1*norm_modulator_signal, label="modulated signal", c="green")
axes_sine_mod[5].set_title("Modulated original signal")
axes_sine_mod[5].set_xlabel("Time (s)")
axes_sine_mod[5].set_ylabel("Signal value")

axes_sine_mod[5].legend()

plt.show()

# %% [markdown]
# ## Task 4
#
# ### Spectral density of single sine wave

# %%
T_sine_spect = 2*np.pi
t_sine_spect = T_sine_spect

sine_spect_time, sine_spect_signal = SineWave(t_sine_spect, T_sine_spect, A=1)

# %%
# Power spectrum calculations
power_spectrum_sine_spect = np.abs(np.fft.rfft(sine_spect_signal))**2

freqs_sine_spect = np.abs(np.fft.fftfreq(power_spectrum_sine_spect.size, t_sine_spect/power_spectrum_sine_spect.size))
idx_sine_spect = np.argsort(freqs_sine_spect)

# %%
nrows = 4
ncols = 1
fig_sine_spect, axes_sine_spect = plt.subplots(nrows=nrows, ncols=ncols, figsize=(14,28))

axes_sine_spect[0].plot(sine_spect_time, sine_spect_signal, c="red")
axes_sine_spect[0].set_xlabel("Time (s)")
axes_sine_spect[0].set_ylabel("Signal value")

axes_sine_spect[1].plot(freqs_sine_spect[idx_sine_spect], power_spectrum_sine_spect[idx_sine_spect])
axes_sine_spect[1].set_title("Power density spectrum (PDS)")
axes_sine_spect[1].set_xlabel("Frequency [Hz]")
axes_sine_spect[1].set_ylabel("$Amplitude^2$")
axes_sine_spect[1].set_xscale("log")

axes_sine_spect[2].plot(np.sqrt(power_spectrum_sine_spect))
axes_sine_spect[2].set_title("Amplitude density spectrum (ADS)")
axes_sine_spect[2].set_xlabel("Frequency [Hz]")
axes_sine_spect[2].set_ylabel("|Amplitude|")
axes_sine_spect[2].set_xscale("log")

# Spectrogram
axes_sine_spect[3].specgram(sine_spect_signal, NFFT=1024, Fs=128, noverlap=512)
axes_sine_spect[3].set_title("Spectrogram")
axes_sine_spect[3].set_xlabel("Time ($s$)")
axes_sine_spect[3].set_ylabel("Frequency [$Hz$]")
#axes_sine_spect[3].set_xlim(0,np.pi*2)

plt.show()

# %% [markdown]
# ## Task 5
#
# ### Discrete Fourier transform optimalization

# %%
from datetime import datetime
from datetime import timedelta

# %%
t_disc = 150

disc_sine_time_1, disc_sine_signal_1 = SineWave(t_disc, T=2*np.pi, A=1)
disc_sine_time_2, disc_sine_signal_2 = SineWave(t_disc, T=np.pi, A=2)

# %%
fig_sine_disc, axes_sine_disc = plt.subplots(nrows=2, ncols=1, figsize=(14,14))

axes_sine_disc[0].plot(disc_sine_time_1, disc_sine_signal_1, c="red")
axes_sine_disc[0].set_title("Sine wave #1")
axes_sine_disc[0].set_xlabel("Time (s)")
axes_sine_disc[0].set_ylabel("Signal value")

axes_sine_disc[1].plot(disc_sine_time_2, disc_sine_signal_2, c="red")
axes_sine_disc[1].set_title("Sine wave #2")
axes_sine_disc[1].set_xlabel("Time (s)")
axes_sine_disc[1].set_ylabel("Signal value")


plt.show()

# %% [markdown]
# #### Implement Fourier transform optimalization
#
# If $x \left[ n \right]$ and $y \left[ n \right]$ is Furier transformable discrete functions, then if we take the following sum:
#
# $$
# x \left[ n \right] + j \cdot y \left[ n \right]
# $$

# %%
disc_added_signal = disc_sine_signal_1 + 1.0j * disc_sine_signal_2

# %%
disc_added_signal_real = disc_sine_signal_1 + disc_sine_signal_2

# %% [markdown]
# ##### Native case

# %%
### Measuring time
native_time_start = datetime.now()

disc_signal_FFTd_1, disc_freqs_FFTd_1 = FFT(disc_sine_signal_1, t_disc)
disc_signal_FFTd_2, disc_freqs_FFTd_2 = FFT(disc_sine_signal_2, t_disc)

native_time_end = datetime.now() - native_time_start

# %% [markdown]
# ##### Optimized case

# %%
### Measuring time
optimized_time_start = datetime.now()

disc_signal_FFTd_opt, disc_freqs_FFTd_opt = FFT(disc_added_signal, t_disc)

optimized_time_end = datetime.now() - optimized_time_start

# %%
disc_signal_FFTd_real, disc_freqs_FFTd_real = FFT(disc_added_signal_real, t_disc)

# %% [markdown]
# #### Difference between the two case

# %%
print("Native case: {0}".format(native_time_end))
print("Optimized case: {0}".format(optimized_time_end))

print("The optimized case was {0:.3f} time faster than native case.".format(native_time_end/optimized_time_end))
# Out:
# Native case: 0:00:00.023897
# Optimized case: 0:00:00.008687
# The optimized case was 2.751 time faster than native case.

# %% [markdown]
# #### Plot the various Fourier transforms

# %%
fig_disc, axes_disc = plt.subplots(nrows=2, ncols=1, figsize=(21,28))

axes_disc[0].plot(disc_freqs_FFTd_1, disc_signal_FFTd_1.real, label="Sine wave #1", c="red")
axes_disc[0].plot(disc_freqs_FFTd_2, disc_signal_FFTd_2.real, label="Sine wave #2", c="orange")
axes_disc[0].plot(disc_freqs_FFTd_opt, disc_signal_FFTd_opt.real, label="Addition", c="green")

axes_disc[1].plot(disc_freqs_FFTd_1, disc_signal_FFTd_1.real, label="Sine wave #1", c="red")
axes_disc[1].plot(disc_freqs_FFTd_2, disc_signal_FFTd_2.real, label="Sine wave #2", c="orange")
axes_disc[1].plot(disc_freqs_FFTd_real, disc_signal_FFTd_real.real, label="Addition", c="green")
axes_disc[1].plot(disc_freqs_FFTd_1, (disc_signal_FFTd_1 + disc_signal_FFTd_2).real, linestyle='--', label="Fourier addition", c="black")


axes_disc[0].set_title("Original and added signals")
axes_disc[0].set_xlabel("Frequencies")
axes_disc[0].set_ylabel("Signal value, frequency domain")

axes_disc[1].set_title("Original and added signals")
axes_disc[1].set_xlabel("Frequencies")
axes_disc[1].set_ylabel("Signal value, frequency domain")

xlim_0 = 150
ylim_0 = 100
axes_disc[0].set_xlim(-xlim_0,xlim_0)
axes_disc[0].set_ylim(-ylim_0,ylim_0)

xlim_1 = 20
ylim_1 = 100
axes_disc[1].set_xlim(-xlim_1,xlim_1)
axes_disc[1].set_ylim(-ylim_1,ylim_1)

plt.legend()
plt.show()

# %% [markdown]
# #### Gather the original Fourier transforms
#
# ##### Addition Theorem:
#
# $$
# \mathcal{F} \left[ f + g \right] = F + G
# $$
#
# ##### Proof:
#
# $$
# \mathcal{F} \left[ f + g \right] (s) = \int^{\infty}_{-\infty} \left[ f(t) + g(t) \right] \cdot e^{− 2j \pi st} dt
# =
# \int^{\infty}_{-\infty} f(t) \cdot e^{− 2j \pi st} dt +
# \int^{\infty}_{-\infty} g(t) \cdot e^{− 2j \pi st} dt
# =
# F(s) + G(s)
# $$

# %% [markdown]
# ## Task 6

# %% [markdown]
# ## Task 7-8

# %%
T_sine_sampling = 2*np.pi
t_sine_sampling = T_sine_sampling * 2
A_sine_sampling = 1

sine_sampling_time, sine_sampling_signal = SineWave(t_sine_sampling, T_sine_sampling, A=A_sine_sampling)

# %%
def SineWaveContinuous(t, T=T_sine_sampling, A=A_sine_sampling):
    
    T /= 2 * np.pi
    signal = np.sin(t / T) * A
    
    return(signal)

# %% [markdown]
# ### Sampling with 100% precision

# %%
def SamplingSignalPrec(t_sine_sampling, SamplingTime=False, SamplingRate=False):
    
    if(SamplingTime != False and SamplingRate == False):
        
        # Sampling rate: SampTime Hz/second
        SampRate = int(t_sine_sampling / SamplingTime)
        time = np.linspace(0, t_sine_sampling, SampRate, endpoint=True)

        # np.array for containting values of current function
        signal = np.empty(SampRate)

        i = 0
        while(i < SampRate):

            signal[i] = SineWaveContinuous(time[i], T=2*np.pi, A=1)
            i += 1

        return(time, signal)
        
    elif(SamplingTime == False and SamplingRate != False):
        
        # Sampling rate: SamplingRate Hz/second
        SampRate = int(t_sine_sampling * SamplingRate)
        time = np.linspace(0, t_sine_sampling, SampRate, endpoint=True)

        # np.array for containting values of current function
        signal = np.empty(SampRate)

        i = 0
        while(i < SampRate):
    
            signal[i] = SineWaveContinuous(t=time[i], T=T_sine_sampling, A=A_sine_sampling)
            i += 1

        return(time, signal)
        
    else:
        print("Action permitted!")

# %%
sine_sampled_prec_time_1, sine_sampled_prec_signal_1 = SamplingSignalPrec(t_sine_sampling, SamplingTime=False, SamplingRate=1)
sine_sampled_prec_time_3, sine_sampled_prec_signal_3 = SamplingSignalPrec(t_sine_sampling, SamplingTime=False, SamplingRate=3)
sine_sampled_prec_time_5, sine_sampled_prec_signal_5 = SamplingSignalPrec(t_sine_sampling, SamplingTime=False, SamplingRate=5)

# %% [markdown]
# ### Sampling with $\delta t$ errors

# %%
def PositiveNegativeSample():
    
    return -1 if np.random.rand() < 0.5 else 1


def RandomStepSample(t, SampRate):
    
    dt = (t/SampRate)/10
    RandomStep = np.random.randint(0,10) * dt * PositiveNegativeSample()
    
    return RandomStep

# %%
def SamplingSignalRand(t_sine_sampling, SamplingTime=False, SamplingRate=False):
    
    if(SamplingTime != False and SamplingRate == False):
        
        # Sampling rate: SampTime Hz/second
        SampRate = int(t_sine_sampling / SamplingTime)

        # np.array for containting values of current function
        time = np.empty(SampRate)
        signal = np.empty(SampRate)

        i = 0
        while(i < SampRate):

            time[i] = i * t_sine_sampling/SampRate
            signal[i] = SineWaveContinuous(time[i], T=2*np.pi, A=1)
            
            time[i] += RandomStepSample(t_sine_sampling, SampRate)
            
            i += 1

        return(time, signal)
        
    elif(SamplingTime == False and SamplingRate != False):
        
        # Sampling rate: SamplingRate Hz/second
        SampRate = int(t_sine_sampling * SamplingRate)

        # np.array for containting values of current function
        time = np.empty(SampRate)
        signal = np.empty(SampRate)

        i = 0
        while(i < SampRate):
    
            time[i] = i * t_sine_sampling/SampRate
            signal[i] = SineWaveContinuous(t=time[i], T=T_sine_sampling, A=A_sine_sampling)
            
            time[i] += RandomStepSample(t_sine_sampling, SampRate)
            
            i += 1

        return(time, signal)
        
    else:
        print("Action permitted!")

# %%
sine_sampled_rand_time_1, sine_sampled_rand_signal_1 = SamplingSignalRand(t_sine_sampling, SamplingTime=False, SamplingRate=1)
sine_sampled_rand_time_3, sine_sampled_rand_signal_3 = SamplingSignalRand(t_sine_sampling, SamplingTime=False, SamplingRate=3)
sine_sampled_rand_time_5, sine_sampled_rand_signal_5 = SamplingSignalRand(t_sine_sampling, SamplingTime=False, SamplingRate=5)

# %%
nrows=3
ncols=1
fig_sine_sampling, axes_sine_sampling = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols*14,nrows*7))

axes_sine_sampling[0].plot(sine_sampling_time, sine_sampling_signal, c="red")

axes_sine_sampling[0].set_title("Original signal")
axes_sine_sampling[0].set_xlabel("Time (s)")
axes_sine_sampling[0].set_ylabel("Signal value")


axes_sine_sampling[1].scatter(sine_sampled_prec_time_5, sine_sampled_prec_signal_5, c='orange', label="5 Hz/seconds")
axes_sine_sampling[1].scatter(sine_sampled_prec_time_3, sine_sampled_prec_signal_3, c='green', label="3 Hz/seconds")
axes_sine_sampling[1].scatter(sine_sampled_prec_time_1, sine_sampled_prec_signal_1, c='red', label="1 Hz/seconds")

axes_sine_sampling[1].set_title("Sampled signals with 100% precision")
axes_sine_sampling[1].set_xlabel("Time (s)")
axes_sine_sampling[1].set_ylabel("Signal value")


axes_sine_sampling[2].scatter(sine_sampled_rand_time_5, sine_sampled_rand_signal_5, c='orange', label="5 Hz/seconds")
axes_sine_sampling[2].scatter(sine_sampled_rand_time_3, sine_sampled_rand_signal_3, c='green', label="3 Hz/seconds")
axes_sine_sampling[2].scatter(sine_sampled_rand_time_1, sine_sampled_rand_signal_1, c='red', label="1 Hz/seconds")

axes_sine_sampling[2].set_title("Sampled signals with $\delta t$ precision")
axes_sine_sampling[2].set_xlabel("Time (s)")
axes_sine_sampling[2].set_ylabel("Signal value")

axes_sine_sampling[1].legend()
axes_sine_sampling[2].legend()

plt.show()

# %% [markdown]
# ### Calculate spectrums

# %%
# Power spectrum calculations
power_spectrum_sample_prec_1 = np.abs(np.fft.rfft(sine_sampled_prec_signal_1))**2
power_spectrum_sample_prec_3 = np.abs(np.fft.rfft(sine_sampled_prec_signal_3))**2
power_spectrum_sample_prec_5 = np.abs(np.fft.rfft(sine_sampled_prec_signal_5))**2

power_spectrum_sample_rand_1 = np.abs(np.fft.rfft(sine_sampled_rand_signal_1))**2
power_spectrum_sample_rand_3 = np.abs(np.fft.rfft(sine_sampled_rand_signal_3))**2
power_spectrum_sample_rand_5 = np.abs(np.fft.rfft(sine_sampled_rand_signal_5))**2


freqs_sample_prec_1 = np.abs(np.fft.fftfreq(power_spectrum_sample_prec_1.size, t_sine_sampling/power_spectrum_sample_prec_1.size))
freqs_sample_prec_3 = np.abs(np.fft.fftfreq(power_spectrum_sample_prec_3.size, t_sine_sampling/power_spectrum_sample_prec_3.size))
freqs_sample_prec_5 = np.abs(np.fft.fftfreq(power_spectrum_sample_prec_5.size, t_sine_sampling/power_spectrum_sample_prec_5.size))

freqs_sample_rand_1 = np.abs(np.fft.fftfreq(power_spectrum_sample_rand_1.size, t_sine_sampling/power_spectrum_sample_rand_1.size))
freqs_sample_rand_3 = np.abs(np.fft.fftfreq(power_spectrum_sample_rand_3.size, t_sine_sampling/power_spectrum_sample_rand_3.size))
freqs_sample_rand_5 = np.abs(np.fft.fftfreq(power_spectrum_sample_rand_5.size, t_sine_sampling/power_spectrum_sample_rand_5.size))


idx_sample_prec_1 = np.argsort(freqs_sample_prec_1)
idx_sample_prec_3 = np.argsort(freqs_sample_prec_3)
idx_sample_prec_5 = np.argsort(freqs_sample_prec_5)

idx_sample_rand_1 = np.argsort(freqs_sample_rand_1)
idx_sample_rand_3 = np.argsort(freqs_sample_rand_3)
idx_sample_rand_5 = np.argsort(freqs_sample_rand_5)

# %%
nrows=4
ncols=1
fig_sampling_spect, axes_sampling_spect = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols*14,nrows*7))

axes_sampling_spect[0].plot(freqs_sample_prec_1[idx_sample_prec_1], power_spectrum_sample_prec_1[idx_sample_prec_1], c='red', label="1 Hz/seconds")
axes_sampling_spect[0].plot(freqs_sample_prec_3[idx_sample_prec_3], power_spectrum_sample_prec_3[idx_sample_prec_3], c='green', label="3 Hz/seconds")
axes_sampling_spect[0].plot(freqs_sample_prec_5[idx_sample_prec_5], power_spectrum_sample_prec_5[idx_sample_prec_5], c='orange', label="5 Hz/seconds")

axes_sampling_spect[0].set_title("Power density spectrum (PDS) - Precise, no $\delta t$ error")
axes_sampling_spect[0].set_xlabel("Frequency [Hz]")
axes_sampling_spect[0].set_ylabel("Amplitude^2")
axes_sampling_spect[0].set_xscale("log")


axes_sampling_spect[1].plot(freqs_sample_rand_1[idx_sample_rand_1], power_spectrum_sample_rand_1[idx_sample_rand_1], c='red', label="1 Hz/seconds")
axes_sampling_spect[1].plot(freqs_sample_rand_3[idx_sample_rand_3], power_spectrum_sample_rand_3[idx_sample_rand_3], c='green', label="3 Hz/seconds")
axes_sampling_spect[1].plot(freqs_sample_rand_5[idx_sample_rand_5], power_spectrum_sample_rand_5[idx_sample_rand_5], c='orange', label="5 Hz/seconds")

axes_sampling_spect[1].set_title("Power density spectrum (PDS) - Random $\delta t$ error")
axes_sampling_spect[1].set_xlabel("Frequency [Hz]")
axes_sampling_spect[1].set_ylabel("Amplitude^2")
axes_sampling_spect[1].set_xscale("log")


axes_sampling_spect[2].plot(np.sqrt(power_spectrum_sample_prec_1), c='red', label="1 Hz/seconds")
axes_sampling_spect[2].plot(np.sqrt(power_spectrum_sample_prec_3), c='green', label="3 Hz/seconds")
axes_sampling_spect[2].plot(np.sqrt(power_spectrum_sample_prec_5), c='orange', label="5 Hz/seconds")

axes_sampling_spect[2].set_title("Amplitude density spectrum (ADS) - Precise, no $\delta t$ error")
axes_sampling_spect[2].set_xlabel("Frequency [Hz]")
axes_sampling_spect[2].set_ylabel("|Amplitude|")
axes_sampling_spect[2].set_xscale("log")


axes_sampling_spect[3].plot(np.sqrt(power_spectrum_sample_rand_1), c='red', label="1 Hz/seconds")
axes_sampling_spect[3].plot(np.sqrt(power_spectrum_sample_rand_3), c='green', label="3 Hz/seconds")
axes_sampling_spect[3].plot(np.sqrt(power_spectrum_sample_rand_5), c='orange', label="5 Hz/seconds")

axes_sampling_spect[3].set_title("Amplitude density spectrum (ADS) - Random $\delta t$ error")
axes_sampling_spect[3].set_xlabel("Frequency [Hz]")
axes_sampling_spect[3].set_ylabel("|Amplitude|")
axes_sampling_spect[3].set_xscale("log")


axes_sampling_spect[0].legend()
axes_sampling_spect[1].legend()
axes_sampling_spect[2].legend()
axes_sampling_spect[3].legend()

plt.show()

# %% [markdown]
# ## Task 9

# %% [markdown]
# ## Task 10
