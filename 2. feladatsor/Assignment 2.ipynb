# %% [markdown]
# # Signal processing course 2018/2019-1 @ ELTE
# # Assignment 2
# ## 10.01.2018

# %% [markdown]
# ## Task 1
#
# ### Addition of periodic signals
#
# #### Definition of periodicity
#
# A real function is said to be periodic if there exists a real number $P > 0$ so that $f(t+P) = f(t)$ for all $t$. The number $P$ is said to be a period of the function.
#
# The sum of two periodic functions is often periodic, but not always. Suppose that $x_{1}(t)$ is periodic with least period $T_{1}$, and $x_{2}(t)$ is periodic with least period $T_{2}$. If $T_{1}$ and $T_{2}$ have a common multiple $T$, then $x_{1}(t) + x_{2}(t)$ is periodic with period $T$. However, $T$ is not necessarily the *least* period of $x_{1}(t) + x_{2}(t)$.
#
# To give an extreme example
#
# $$
# \sin(t) + -\sin(t)
# $$
#
# has no least period.
#
# #### Criterion for sum of periodic functions
#
# If the periods of two periodic functions do not have a common multiple, then their sum is not periodic. Perhaps the simplest example is
#
# $$
# \sin(t) + \sin(\pi t)
# $$
#
# whose terms have least periods $2 \pi$ and $2$ respectively
#
# ***

# %% [markdown]
# ## Task 2-3 - Part 1
#
# ### Fourier series [\[1\]](https://en.wikipedia.org/wiki/Fourier_series)
#
# #### Definition of Fourier series
#
# Here $f(x)$ denotes a function of the real variable $x$, and $f$ is integrable on an interval $[x_{0}, x_{0} + T]$, for real numbers $x_{0}$ and $T$. Fourier series attempt to represent $f$ in that interval as an infinite sum/series, of harmonically related sinusoidal functions.
#
# Outside the interval, the series is periodic with period $T$ (frequency $1/T$). It follows that if $f$ also has that property, the approximation is valid on the entire real line. We can begin with a finite summation (or partial sum):
#
# $$
# f_{N}(x) = \frac{A_{0}}{2} + \sum_{n = 1}^{N} A_{k} \cdot \sin \left(\frac {2\pi kx}{T} + \phi _{k} \right) \quad \text{for integers}\ N\ \geq \ 1
# $$
#
# We can also write the function in this equivalent form:
#
# $$
# f_{N}(x) = \overbrace{a_{0}}^{A_{0}}/2 + \sum_{k = 1}^N \left( \overbrace{a_{k}}^{A_{k} \sin(\phi_{k})} \cdot \cos \left( \frac{2\pi k x}{T} \right) + \overbrace{b_{k}}^{A_{k} \cos(\phi_{k})} \cdot \sin \left( \frac{2\pi k x}{T} \right) \right) = \sum_{k = -N}^N c_{k} \cdot e^{i \tfrac{2\pi k x}{T}}
# $$
#
# where
#
# $$
# \frac{2 \pi}{T} = \omega_{0}
# $$
#
# So which we could write in te following form too:
#
# $$
# f_{N}(x) = \overbrace{a_{0}}^{A_{0}}/2 + \sum_{k = 1}^N \left( \overbrace{a_{k}}^{A_{k} \sin(\phi_{k})} \cdot \cos \left( k \omega_{0} x \right) + \overbrace{b_{k}}^{A_{k} \cos(\phi_k)} \cdot \sin \left( k \omega_{0} x \right) \right) = \sum_{k = -N}^N c_{k} \cdot e^{i k \omega_{0} x}
# $$
#
# and where
#
# $$
# c_k \ \stackrel{\mathrm{def}}{=} \
# \begin{cases}
#     \frac{A_{k}}{2i} e^{i \phi_{k}} = \frac{1}{2} (a_{k} - i b_{k}) & \text{for }k > 0 \\
#     \frac{1}{2} A_0 = \frac{1}{2} a_{0} & \text{for }k = 0 \\
#     c_{|k|}^* & \text{for }k < 0
# \end{cases}
# $$
#
# The inverse relationships between the coefficients are:
#
# $$
# A_{k} = \sqrt{a_{k}^{2} + b_{k}^{2}}, \quad \phi _{k} = \operatorname{arctan} \left( \frac{a_{k}}{b_{k}} \right)
# $$
#
# When the coefficients (known as Fourier coefficients) are computed as follows:
#
# $$
# a_{k} = \frac{2}{T} \int_{x_{0}}^{x_{0} + T} f(x) \cdot \cos \left( \frac{2\pi k x}{T} \right)\ dx = \frac{2}{T} \int_{x_{0}}^{x_{0} + T} f(x) \cdot \cos \left( k \omega_{0} x \right)\ dx
# $$
#
# $$
# b_{k} = \frac{2}{T} \int_{x_{0}}^{x_{0} + T} f(x) \cdot \sin \left( \frac{2\pi k x}{T} \right)\ dx = b_{k} = \frac{2}{T} \int_{x_{0}}^{x_{0} + T} f(x) \cdot \sin \left( k \omega_{0} x \right)\ dx
# $$
#
# $$
# c_{k} = \frac{1}{T} \int_{x_{0}}^{x_{0} + T} f(x) \cdot e^{-i \frac{2\pi k x}{T}}\ dx = \frac{1}{T} \int_{x_{0}}^{x_{0} + T} f(x) \cdot e^{-i k \omega_{0} x}\ dx
# $$
#
# ***

# %% [markdown]
# ### Symmetry properties of Fourier series [\[2\]](https://www.youtube.com/watch?v=YmYU-u_pFZY)
#
# #### 1) Even-Function Symmetry
#
# First we examine the case, where the function is even, so
#
# $$
# f(t) = f(-t)
# $$
#
# For any even periodic functions, the equations for the Fourier coefficients simplify to the following:
#
# $$
# a_{k} = \frac{4}{T} \int_{0}^{T/2} f(t) \cos \left( k \omega_{0} t \right)\ dt
# $$
#
# $$
# b_{k} = 0 \quad \text{for all }k
# $$
#
#
# #### 2) Odd-Function Symmetry
#
# They call a function *odd*, if it has the following property:
#
# $$
# f(t) = - f(t)
# $$
#
# In this case, the expressions for the Fourier coefficients are as follows:
#
# $$
# a_{k} = 0 \quad \text{for all }k
# $$
#
# $$
# b_{k} = \frac{4}{T} \int_{0}^{T/2} f(t) \sin \left( k \omega_{0} \right)\ dt
# $$
#
#
# #### 3) Time shifting/Translation
#
# For every real $\tau$, if
#
# $$
# f(t') = f(t \pm \tau)
# $$
#
# then
#
# $$
# c_{k} = e^{\pm i k \omega_{0} \tau} \cdot \frac{1}{T} \int_{t_{0}}^{t_{0} + T} f(t) \cdot e^{-i k \omega_{0} t}\ dt
# $$
#
#
# #### 4) Frequency shifting/Frequency modulation
#
# The frequency shifting property states that if
#
# $$
# h(t) = e^{−i k_{0} \omega_{0} t} \cdot f(t)
# $$
#
# then
#
# $$
# c_{k} = c_{k - k_{0}}
# $$
#
# so
#
# $$
# c_{k} = \frac{1}{T} \int_{t_{0}}^{t_{0} + T} f(t) \cdot e^{-i (k-k_{0}) \omega_{0} t}\ dt
# $$
#
#
# #### 5) Time reversal
#
# We examine the case, where
#
# $$
# f \left( t' \right) = f(-t)
# $$
#
# Then
#
# $$
# c_{k} \Longrightarrow c_{-k} = \frac{1}{T} \int_{t_{0}}^{t_{0} + T} f \left( t' \right) \cdot e^{-i (-k) \omega_{0} t'} \ dt'
# $$
#
#
# #### 6) Differentiation
#
# If
#
# $$
# h(t) = \frac{df(t)}{dt}
# $$
#
# then
#
# $$
# c_{k} = i k \omega_{0} \cdot \frac{1}{T} \int_{t_{0}}^{t_{0} + T} f(t) \cdot e^{-i k \omega_{0} t}\ dt
# $$
#
#
# #### 7) Multiplication/Amplitude modulation [\[3\]](https://link.springer.com/content/pdf/bbm%3A978-1-4020-4818-0%2F1.pdf)
#
# If
#
# $$
# h(t) = f(t) \cdot g(t)
# $$
#
# and the following is true:
#
# $$
# c_{k_{f}} = \frac{1}{T} \int_{t_{0}}^{t_{0} + T} f(t) \cdot e^{-i k \omega_{0} t}\ dt,
# \quad
# c_{k_{g}} = \frac{1}{T} \int_{t_{0}}^{t_{0} + T} g(t) \cdot e^{-i k \omega_{0} t}\ dt
# $$
#
# then
#
# $$
# c_{k_{h}} = \sum_{i = -\infty}^{\infty} c_{i_{f}} c_{(k-i)_{g}}
# $$
#
# ***
# ***

# %% [markdown]
# ### Fourier transform
#
# #### Definition of Fourier transform [\[4\]](https://en.wikipedia.org/wiki/Fourier_transform)
#
# The Fourier transform of the function $f$ is traditionally denoted by adding a circumflex: $\hat{f}$, or using the $\mathcal{F}$ symbol. There are several common conventions for defining the Fourier transform of an integrable function $f:\mathbb{R} \to \mathbb{C}$. Here we will use the following definition:
#
# $$
# \hat{f}(\xi) = \int_{-\infty}^{\infty} f(x) e^{-2\pi i x \xi}\ dx
# $$
#
# When the independent variable $x$ represents time (noted by $t$), the transform variable $\xi$ represents frequency (noted by $\omega$) E.g. if time is measured in $s$, then the frequency is in $1/s$. Under suitable conditions, $f$ is determined by $\hat{f}$ via the inverse transform:
#
# $$
# f(x) = \int_{-\infty}^{\infty} \hat{f}(\xi) e^{2\pi i x \xi}\ d\xi
# $$
#
# for any real number $x$.
#
# #### Convolution [\[5\]](http://web.stanford.edu/class/ee102/lectures/samp_mod.pdf)
#
# Suppose $f(x)$, $g(x)$ have the Fourier transform $\hat{f}(\xi)$, $\hat{g}(\xi)$, the *convolution* $y = f * g$ of $f$ and $g$ is given by
#
# $$
# y(t) = \int_{-\infty}^{\infty} f(\tau) g(x - \tau)\ d\tau
# $$
#
# Therefore
#
# $$
# \hat{y}(\xi) = \hat{f}(\xi)\hat{g}(\xi)
# $$
#
# (E.g. convolution in the time domain corresponds to multiplication in the frequency domain.)
#
# ***

# %% [markdown]
# ### Symmetry properties of Fourier transform [\[6\]](http://fourier.eng.hmc.edu/e101/lectures/handout3/node2.html)
#
# #### 1) Translation/Time shifting
#
# For any real number $x_{0}$, if
#
# $$
# h(x) = f(x − x_{0})
# $$
#
# then
#
# $$
# \hat{h}(\xi) = e^{−2\pi x_{0} \xi} \hat{f}(\xi)
# $$
#
# #### 2) Frequency shifting/Frequency modulation
#
# For any real number $\xi_{0}$, if
#
# $$
# h(x) = e^{2 \pi ix \xi_{0}} f(x)
# $$
#
# then
#
# $$
# \hat{h}(\xi) = \hat{f}(\xi − \xi_{0})
# $$
#
# #### 3) Time reversal
#
# If
#
# $$
# h(x) = f(−x)
# $$
#
# then
#
# $$
# \mathcal{F} \left[ {h}(-x) \right] = \hat{h}(-\xi)
# $$
#
# #### 4) Conjugation
#
# If $h(x) = \overline{f(x)}$, then
#
# $$
# \hat{h}(\xi) = \overline{\hat{f}(-\xi)}
# $$
#
# In particular, if $f$ is real, then one has the reality condition
#
# $$
# \hat{f}(-\xi) = \overline {\hat{f}(\xi)}
# $$
#
# that is, $\hat{f}$ is a Hermitian function. And if $f$ is purely imaginary, then
#
# $$
# \hat{f}(-\xi)  = -\overline{\hat {f}(\xi)}
# $$
#
# #### 5) Differentiation
#
# Suppose $f(x)$ is a differentiable function, and both $f$ and its derivative $f′$ are integrable. Then the Fourier transform of the derivative is given by
#
# $$
# \widehat{f'}(\xi) = 2 \pi i \xi \hat{f}(\xi)
# $$
#
# More generally, the Fourier transformation of the $n$th derivative $f^{(n)}$ is given by
#
# $$
# \widehat{f^{(n)}}(\xi)= (2 \pi i \xi)^{n} \hat{f}(\xi)
# $$
#
# ***
# ***

# %% [markdown]
# ### Test properties of Fourier series numerically<sup>[1](#footnote1)</sup>
#
# Fourier coefficients can be approximated by numeric integration. With the use of the trapezoid formulation in the case of the $N + 1$
#
# $$
# x_{\nu} = \nu h
# \quad
# \left( \nu = 0,1, \dots ,N \right),
# \quad
# h = \frac{2 \pi}{N}
# $$
#
# equidistant base point, the following approximate formula is obtained:
#
# $$
# a_{k} \approx \tilde{a}_{k} = \frac{2}{N} \sum_{\nu = 1}^{N} f(t_{\nu}) \cos \left( k t_{\nu} \right),
# \quad
# b_{k} \approx \tilde{b}_{k} = \frac{2}{N} \sum_{\nu = 1}^{N} f(t_{\nu}) \sin \left( k t_{\nu} \right),
# \quad
# \left( k = 0,1, \dots ,n \right).
# $$
#
# By analogy, the following formula can be used for $c_{k}$ coefficients:
#
# $$
# c_{k} = \frac{1}{N} \sum_{\nu = 0}^{N - 1} f(t_{\nu}) e^{-i k t_{\nu}} = \sum_{\nu = 0}^{N - 1} f_{\nu} \omega_{N}^{k \nu},
# \quad
# \left( k = 0,1, \dots ,n \right)
# $$
#
# where
#
# $$
# f_{\nu} = \frac{1}{N} f(t_{\nu}),
# \quad
# t_{\nu} = \frac{2 \pi \nu}{N},
# \quad
# \left( \nu = 0,1, \dots ,N-1 \right),
# \quad
# \omega_{N} = e^{-\tfrac{2 \pi i}{N}}.
# $$
#
# <a name="footnote1">1</a>: Bronstein, 2009. Typotex, p. 952

# %%
import scipy
import cmath
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %% [markdown]
# ##### Test

# %% [markdown]
# ## Task 2-3 - Part 2
#
# ### Fourier series of various signals

# %% [markdown]
# #### Calculate Fourier coefficients
#
# Given a periodic, function $f(t)$ with period $T$, this function returns the
# coefficients
#
# $$
# a_{0}, \quad \{a_{1}, a_{2}, \dots \}, \quad \{ b_{1}, b_{2}, \dots \}
# $$
#
# such that:
#
# $$
# f(t) \approx \frac{a_{0}}{2} + \sum_{k = 1}^{N} \left( a_{k} \cdot \cos \left( \frac{2 \pi k t}{T} \right) + b_{k} \cdot \sin \left( \frac{2 \pi k t}{T} \right) \right)
# $$
#
# If Complex is set to True, it returns instead the coefficients
#
# $$
# \{c_{0}, c_{1}, \dots \}
# $$
#
# such that:
#
# $$
# f(t) \approx \sum_{k = -N}^{N} c_{k} \cdot e^{i\tfrac{2 \pi k t}{T}}
# $$
#
# where we define
#
# $$
# c_{-n} =c_{|n|}^{*}
# $$

# %%
def FourierCoeff(signal, t, N_max, Complex=False):
    
    '''
    Parameters
    ----------
    signal : the periodic function's value as an np.array
    t: an np.linsapce array of points of time, where the signal got evalueted
    N_max : the function will return the first N_max + 1 Fourier coefficients

    Returns
    -------
    if Complex == False, the function returns:

    a_0 : float
    a, b : np.float arrays describing respectively the cosine and sine coefficients

    =======
    if Complex == True, the function returns:

    c : 1-dimensional complex-valued np.array of size N+1
    '''

    # This function computes the one-dimensional n-point discrete Fourier Transform (DFT) 
    # of a real-valued array by means of an efficient algorithm called the Fast Fourier Transform (FFT)
    y = np.fft.rfft(signal) / t.size

    if(Complex):
        return(y)
    else:
        y *= 2
        return(y[0].real, y[1:-1].real, -y[1:-1].imag)

# %% [markdown]
# #### Reconstruct original function with Fourier coefficients

# %%
def FourierCalcReal(a_0, a, b, t, T, N_max):
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    ReconstTime = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array to store the reconstructed function's values
    ReconstFunc = np.empty(SampRate)
    
    # Calculate f(t) values by f(t) ~= a_0/2 + {Sum}_k=1->N (a_k*cos(2*pi*kt/T) + b_k*sin(2*pi*kt/T))
    for dt in range(0,len(ReconstTime)):
        ReconstFunc[dt] = a_0/2
        
        for k in range(1,N_max):
            ReconstFunc[dt] += a[k-1] * np.cos(2 * np.pi * k * ReconstTime[dt] / T) + b[k-1] * np.sin(2 * np.pi * k * ReconstTime[dt] / T)

    return(ReconstFunc, ReconstTime)

# %%
def FourierCalcComplex(c, t, T):
    pass

# %% [markdown]
# ### Functions
#
# #### 1) Square wave with $\tau$ bandwidth and $T$ period

# %%
def f_1(t, tau, T):
    '''
    Input parameters:
    
    't': time in seconds
    'tau': bandwidth
    'T': period of signal
    '''
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):
        if(((t/SampRate * i) % T) < tau):
            signal[i] = 1
            i += 1
        else:
            signal[i] = 0
            i += 1

    return(time, signal, T, tau)

# %%
def f_1_Fourier(tau, T, N_max):
    
    '''
    Input parameters:
    
    'tau': bandwidth
    'T': period of signal
    'N_max': Index of nth harmonic of Fourier series
    '''
    
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    f_sample = 2 * N_max
    
    # We also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    time = np.linspace(0, T, f_sample + 2, endpoint=False)
    
    # np.array for containting values of current function
    signal = np.empty(f_sample + 2)
    
    i = 0
    while(i < (f_sample + 2)):
        if(((time[f_sample + 1]/(f_sample + 2) * i) % T) < tau):
            signal[i] = 1
            i += 1
        else:
            signal[i] = 0
            i += 1

    return(time, signal, T, tau)

# %%
t_1_Fourier = 16
tau_1_Fourier = 4
T_1_Fourier = 8

time_1, signal_1, T_1_Fourier, tau_1_Fourier = f_1(t_1_Fourier, tau_1_Fourier, T_1_Fourier)

# %%
fig_f_1 = plt.figure(figsize=(10,7))

plt.plot(time_1, signal_1)

plt.title("Square wave with " + str(tau_1_Fourier) + "s bandwidth and " + str(T_1_Fourier) + "s period")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
N_max_1_Fourier = 100

time_1_Fourier, signal_1_Fourier, T_1_Fourier, tau_1_Fourier = f_1_Fourier(tau_1_Fourier, T_1_Fourier, N_max_1_Fourier)

# %% [markdown]
# #### Plot one period of the signal

# %%
fig_f_1_Period = plt.figure(figsize=(10,7))

plt.plot(time_1_Fourier, signal_1_Fourier)

plt.title("Square wave with " + str(tau_1_Fourier) + "s bandwidth and " + str(T_1_Fourier) + "s period\n(Only showing 1 period)")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
a_0_1, a_1, b_1 = FourierCoeff(signal_1_Fourier, time_1_Fourier, N_max_1_Fourier)

# %%
fig_f_1_CoefficientScatter = plt.figure(figsize=(10,7))

plt.scatter(0,a_0_1, label="a_0",c="blue")
plt.scatter(np.linspace(1,N_max_1_Fourier,N_max_1_Fourier), a_1, label="a_k",c="red")
plt.scatter(np.linspace(1,N_max_1_Fourier,N_max_1_Fourier), b_1, label="b_k",c="green")

plt.title("Coefficients of Fourier series")
plt.xlabel("Harmonics (k)")
plt.ylabel("Value of kth coefficient")

#plt.ylim(-0.01,0.01)

plt.legend()
plt.show()

# %%
ReconstFunc_1, ReconstTime_1 = FourierCalcReal(a_0_1, a_1, b_1, t_1_Fourier, T_1_Fourier, N_max_1_Fourier)

# %%
fig_f_1_Reconstruct = plt.figure(figsize=(10,7))

plt.plot(time_1, signal_1, label="Original function", c="green")
plt.plot(ReconstTime_1, ReconstFunc_1, label="Reconstructed function", c="red")

plt.title(str(N_max_1_Fourier) + "th harmonic of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
ReconstFunc_1_5, ReconstTime_1_5 = FourierCalcReal(a_0_1, a_1, b_1, t_1_Fourier, T_1_Fourier, 5)
ReconstFunc_1_10, ReconstTime_1_10 = FourierCalcReal(a_0_1, a_1, b_1, t_1_Fourier, T_1_Fourier, 10)
ReconstFunc_1_30, ReconstTime_1_30 = FourierCalcReal(a_0_1, a_1, b_1, t_1_Fourier, T_1_Fourier, 30)

# %%
fig_f_1_Reconstruct_Compare = plt.figure(figsize=(10,7))

plt.plot(time_1, signal_1, label="Original function")
plt.plot(ReconstTime_1_5, ReconstFunc_1_5, label="Reconstructed function (5 periods)")
plt.plot(ReconstTime_1_10, ReconstFunc_1_10, label="Reconstructed function (10 periods)")
plt.plot(ReconstTime_1_30, ReconstFunc_1_30, label="Reconstructed function (30 periods)")

plt.title("Comparing various harmonics of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# #### 2) Sawtooth wave

# %%
def f_2(t, T):
    '''
    Input parameters:
    
    't': time in seconds
    'T': period of signal
    '''
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):
        signal[i] = (((t/SampRate) * i) % T) / T
        i += 1
        
    return(time, signal, T)

# %%
t_2_Fourier = 4
T_2_Fourier = 2

time_2, signal_2, T_2_Fourier = f_2(t_2_Fourier, T_2_Fourier)

# %%
fig_f_2 = plt.figure(figsize=(10,7))

plt.plot(time_2, signal_2)

plt.title("Sawtooth wave with " + str(T_2_Fourier) + "s period")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
def f_2_Fourier(T, N_max):
    
    '''
    Input parameters:
    
    'T': period of signal
    'N_max': Index of nth harmonic of Fourier series
    '''
    
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    f_sample = 2 * N_max
    
    # We also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    time = np.linspace(0, T, f_sample + 2, endpoint=False)
    
    # np.array for containting values of current function
    signal = np.empty(f_sample + 2)
    
    i = 0
    while(i < (f_sample + 2)):
        signal[i] = ((time[f_sample + 1]/(f_sample + 2) * i) % T) / T
        i += 1

    return(time, signal, T)

# %%
N_max_2_Fourier = 30

time_2_Fourier, signal_2_Fourier, T_2_Fourier = f_2_Fourier(T_2_Fourier, N_max_2_Fourier)

# %% [markdown]
# #### Plot one period of the signal

# %%
fig_f_2_Period = plt.figure(figsize=(10,7))

plt.plot(time_2_Fourier, signal_2_Fourier)

plt.title("Sawtooth wave with " + str(T_2_Fourier) + "s period\n(Only showing 1 period)")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
a_0_2, a_2, b_2 = FourierCoeff(signal_2_Fourier, time_2_Fourier, N_max_2_Fourier)

# %%
fig_f_2_CoefficientScatter = plt.figure(figsize=(10,7))

plt.scatter(0,a_0_2, label="a_0",c="blue")
plt.scatter(np.linspace(1,N_max_2_Fourier,N_max_2_Fourier), a_2, label="a_k",c="red")
plt.scatter(np.linspace(1,N_max_2_Fourier,N_max_2_Fourier), b_2, label="b_k",c="green")

plt.title("Coefficients of Fourier series")
plt.xlabel("Harmonics (k)")
plt.ylabel("Value of kth coefficient")

#plt.ylim(-0.01,0.01)

plt.legend()
plt.show()

# %%
ReconstFunc_2, ReconstTime_2 = FourierCalcReal(a_0_2, a_2, b_2, t_2_Fourier, T_2_Fourier, N_max_2_Fourier)

# %%
fig_f_2_Reconstruct = plt.figure(figsize=(10,7))

plt.plot(time_2, signal_2, label="Original function", c="green")
plt.plot(ReconstTime_2, ReconstFunc_2, label="Reconstructed function", c="red")

plt.title(str(N_max_2_Fourier) + "th harmonic of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
ReconstFunc_2_5, ReconstTime_2_5 = FourierCalcReal(a_0_2, a_2, b_2, t_2_Fourier, T_2_Fourier, 5)
ReconstFunc_2_10, ReconstTime_2_10 = FourierCalcReal(a_0_2, a_2, b_2, t_2_Fourier, T_2_Fourier, 10)
ReconstFunc_2_30, ReconstTime_2_30 = FourierCalcReal(a_0_2, a_2, b_2, t_2_Fourier, T_2_Fourier, 30)

# %%
fig_f_2_Reconstruct_Compare = plt.figure(figsize=(10,7))

plt.plot(time_2, signal_2, label="Original function")
plt.plot(ReconstTime_2_5, ReconstFunc_2_5, label="Reconstructed function (5 periods)")
plt.plot(ReconstTime_2_10, ReconstFunc_2_10, label="Reconstructed function (10 periods)")
plt.plot(ReconstTime_2_30, ReconstFunc_2_30, label="Reconstructed function (30 periods)")

plt.title("Comparing various harmonics of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# #### 3) $f(x) = |x|$, if $x \in [- \pi, \pi]$, with $T = 2 \pi$

# %%
def f_3(t):
    '''
    Input parameter:
    
    't': time in seconds
    '''
    
    T = 2 * np.pi
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):

        if((t/SampRate * i) % T <= T/2):
            signal[i] = 2 * ((t/SampRate * i) % T)
            i += 1
            
        else:
            signal[i] = 2 * (T - ((t/SampRate * i) % T))
            i += 1
        
    return(time, signal, T)

# %%
t_3_Fourier = 15

time_3, signal_3, T_3_Fourier = f_3(t_3_Fourier)

# %%
fig_f_3 = plt.figure(figsize=(10,7))

plt.plot(time_3, signal_3)

plt.title("Triangle wave with " + str(T_3_Fourier) + "s period")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
def f_3_Fourier(N_max):
    '''
    Input parameter:
    
    'N_max': Index of nth harmonic of Fourier series
    '''
    
    T = 2 * np.pi
    
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    f_sample = 2 * N_max
    
    # We also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    time = np.linspace(0, T, f_sample + 2, endpoint=False)
    
    # np.array for containting values of current function
    signal = np.empty(f_sample + 2)
    
    i = 0
    while(i < (f_sample + 2)):
        if((time[f_sample + 1]/(f_sample + 2) * i) % T <= T/2):
            signal[i] = 2 * ((time[f_sample + 1]/(f_sample + 2) * i) % T)
            i += 1
            
        else:
            signal[i] = 2 * (T - ((time[f_sample + 1]/(f_sample + 2) * i) % T))
            i += 1

    return(time, signal, T)

# %%
N_max_3_Fourier = 40

time_3_Fourier, signal_3_Fourier, T_3_Fourier = f_3_Fourier(N_max_3_Fourier)

# %% [markdown]
# #### Plot one period of the signal

# %%
fig_f_3_Period = plt.figure(figsize=(10,7))

plt.plot(time_3_Fourier, signal_3_Fourier)

plt.title("Triangle wave with " + str(T_3_Fourier) + "s period\n(Only showing 1 period)")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
a_0_3, a_3, b_3 = FourierCoeff(signal_3_Fourier, time_3_Fourier, N_max_3_Fourier)

# %%
fig_f_3_CoefficientScatter = plt.figure(figsize=(10,7))

plt.scatter(0,a_0_3, label="a_0",c="blue")
plt.scatter(np.linspace(1,N_max_3_Fourier,N_max_3_Fourier), a_3, label="a_k",c="red")
plt.scatter(np.linspace(1,N_max_3_Fourier,N_max_3_Fourier), b_3, label="b_k",c="green")

plt.title("Coefficients of Fourier series")
plt.xlabel("Harmonics (k)")
plt.ylabel("Value of kth coefficient")

#plt.ylim(-0.01,0.01)

plt.legend()
plt.show()

# %%
ReconstFunc_3, ReconstTime_3 = FourierCalcReal(a_0_3, a_3, b_3, t_3_Fourier, T_3_Fourier, N_max_3_Fourier)

# %%
fig_f_3_Reconstruct = plt.figure(figsize=(10,7))

plt.plot(time_3, signal_3, label="Original function", c="green")
plt.plot(ReconstTime_3, ReconstFunc_3, label="Reconstructed function", c="red")

plt.title(str(N_max_3_Fourier) + "th harmonic of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
ReconstFunc_3_5, ReconstTime_3_5 = FourierCalcReal(a_0_3, a_3, b_3, t_3_Fourier, T_3_Fourier, 5)
ReconstFunc_3_10, ReconstTime_3_10 = FourierCalcReal(a_0_3, a_3, b_3, t_3_Fourier, T_3_Fourier, 10)
ReconstFunc_3_30, ReconstTime_3_30 = FourierCalcReal(a_0_3, a_3, b_3, t_3_Fourier, T_3_Fourier, 30)

# %%
fig_f_3_Reconstruct_Compare = plt.figure(figsize=(10,7))

plt.plot(time_3, signal_3, label="Original function")
plt.plot(ReconstTime_3_5, ReconstFunc_3_5, label="Reconstructed function (5 periods)")
plt.plot(ReconstTime_3_10, ReconstFunc_3_10, label="Reconstructed function (10 periods)")
plt.plot(ReconstTime_3_30, ReconstFunc_3_30, label="Reconstructed function (30 periods)")

plt.title("Comparing various harmonics of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# #### 4) $f(x) = 1+x$, if $x \in [- \pi, \pi]$, with $T = 2 \pi$

# %%
def f_4(t):
    '''
    Input parameter:
    
    't': time in seconds
    '''
    
    T = 2 * np.pi
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):

        signal[i] = 1 + ((t/SampRate * i) % T)
        i += 1

    return(time, signal, T)

# %%
t_4_Fourier = 15

time_4, signal_4, T_4_Fourier = f_4(t_4_Fourier)

# %%
fig_f_4 = plt.figure(figsize=(10,7))

plt.plot(time_4, signal_4)

plt.title("Sawtooth wave with " + str(T_4_Fourier) + "s period, with baseline on y = 1")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
def f_4_Fourier(N_max):
    
    '''
    Input parameters:
    
    'N_max': period of signal
    '''
    
    T = 2 * np.pi
    
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    f_sample = 2 * N_max
    
    # We also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    time = np.linspace(0, T, f_sample + 2, endpoint=False)
    
    # np.array for containting values of current function
    signal = np.empty(f_sample + 2)
    
    i = 0
    while(i < (f_sample + 2)):
        signal[i] = 1 + ((time[f_sample + 1]/(f_sample + 2) * i) % T)
        i += 1

    return(time, signal, T)

# %%
N_max_4_Fourier = 40

time_4_Fourier, signal_4_Fourier, T_4_Fourier = f_4_Fourier(N_max_4_Fourier)

# %% [markdown]
# #### Plot one period of the signal

# %%
fig_f_4_Period = plt.figure(figsize=(10,7))

plt.plot(time_4_Fourier, signal_4_Fourier)

plt.title("Sawtooth wave with " + str(T_4_Fourier) + "s period, with baseline on y = 1\n(Only showing 1 period)")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
a_0_4, a_4, b_4 = FourierCoeff(signal_4_Fourier, time_4_Fourier, N_max_4_Fourier)

# %%
fig_f_4_CoefficientScatter = plt.figure(figsize=(10,7))

plt.scatter(0,a_0_4, label="a_0",c="blue")
plt.scatter(np.linspace(1,N_max_4_Fourier,N_max_4_Fourier), a_4, label="a_k",c="red")
plt.scatter(np.linspace(1,N_max_4_Fourier,N_max_4_Fourier), b_4, label="b_k",c="green")

plt.title("Coefficients of Fourier series")
plt.xlabel("Harmonics (k)")
plt.ylabel("Value of kth coefficient")

#plt.ylim(-0.01,0.01)

plt.legend()
plt.show()

# %%
ReconstFunc_4, ReconstTime_4 = FourierCalcReal(a_0_4, a_4, b_4, t_4_Fourier, T_4_Fourier, N_max_4_Fourier)

# %%
fig_f_4_Reconstruct = plt.figure(figsize=(10,7))

plt.plot(time_4, signal_4, label="Original function", c="green")
plt.plot(ReconstTime_4, ReconstFunc_4, label="Reconstructed function", c="red")

plt.title(str(N_max_4_Fourier) + "th harmonic of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
ReconstFunc_4_5, ReconstTime_4_5 = FourierCalcReal(a_0_4, a_4, b_4, t_4_Fourier, T_4_Fourier, 5)
ReconstFunc_4_10, ReconstTime_4_10 = FourierCalcReal(a_0_4, a_4, b_4, t_4_Fourier, T_4_Fourier, 10)
ReconstFunc_4_30, ReconstTime_4_30 = FourierCalcReal(a_0_4, a_4, b_4, t_4_Fourier, T_4_Fourier, 30)

# %%
fig_f_4_Reconstruct_Compare = plt.figure(figsize=(10,7))

plt.plot(time_4, signal_4, label="Original function")
plt.plot(ReconstTime_4_5, ReconstFunc_4_5, label="Reconstructed function (5 periods)")
plt.plot(ReconstTime_4_10, ReconstFunc_4_10, label="Reconstructed function (10 periods)")
plt.plot(ReconstTime_4_30, ReconstFunc_4_30, label="Reconstructed function (30 periods)")

plt.title("Comparing various harmonics of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# #### 5) $f(x) = x^2$, if $x \in [- \pi, \pi]$, with $T = 2 \pi$

# %%
def f_5(t):
    '''
    Input parameter:
    
    't': time in seconds
    '''
    
    T = 2 * np.pi
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):

        if(((t/SampRate * i) % T) <= T/2):
            signal[i] = ((t/SampRate * i) % T)**2
            i += 1
        else:
            signal[i] = (T - ((t/SampRate * i) % T))**2
            i += 1

    return(time, signal, T)

# %%
t_5_Fourier = 15

time_5, signal_5, T_5_Fourier = f_5(t_5_Fourier)

# %%
fig_f_5 = plt.figure(figsize=(10,7))

plt.plot(time_5, signal_5)

plt.title("f(x) = x^2 wave with " + str(T_5_Fourier) + "s period")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
def f_5_Fourier(N_max):
    
    '''
    Input parameters:
    
    'N_max': period of signal
    '''
    
    T = 2 * np.pi
    
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    f_sample = 2 * N_max
    
    # We also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    time = np.linspace(0, T, f_sample + 2, endpoint=False)
    
    # np.array for containting values of current function
    signal = np.empty(f_sample + 2)
    
    i = 0
    while(i < (f_sample + 2)):
        
        if((time[f_sample + 1]/(f_sample + 2) * i) % T <= T/2):
            signal[i] = ((time[f_sample + 1]/(f_sample + 2) * i) % T)**2
            i += 1
        else:
            signal[i] = (T - ((time[f_sample + 1]/(f_sample + 2) * i) % T))**2
            i += 1

    return(time, signal, T)

# %%
N_max_5_Fourier = 40

time_5_Fourier, signal_5_Fourier, T_5_Fourier = f_5_Fourier(N_max_5_Fourier)

# %% [markdown]
# #### Plot one period of the signal

# %%
fig_f_5_Period = plt.figure(figsize=(10,7))

plt.plot(time_5_Fourier, signal_5_Fourier)

plt.title("f(x) = x^2 wave with " + str(T_5_Fourier) + "s period\n(Only showing 1 period)")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
a_0_5, a_5, b_5 = FourierCoeff(signal_5_Fourier, time_5_Fourier, N_max_5_Fourier)

# %%
fig_f_5_CoefficientScatter = plt.figure(figsize=(10,7))

plt.scatter(0,a_0_5, label="a_0",c="blue")
plt.scatter(np.linspace(1,N_max_5_Fourier,N_max_5_Fourier), a_5, label="a_k",c="red")
plt.scatter(np.linspace(1,N_max_5_Fourier,N_max_5_Fourier), b_5, label="b_k",c="green")

plt.title("Coefficients of Fourier series")
plt.xlabel("Harmonics (k)")
plt.ylabel("Value of kth coefficient")

#plt.ylim(-0.01,0.01)

plt.legend()
plt.show()

# %%
ReconstFunc_5, ReconstTime_5 = FourierCalcReal(a_0_5, a_5, b_5, t_5_Fourier, T_5_Fourier, N_max_5_Fourier)

# %%
fig_f_5_Reconstruct = plt.figure(figsize=(10,7))

plt.plot(time_5, signal_5, label="Original function", c="green")
plt.plot(ReconstTime_5, ReconstFunc_5, label="Reconstructed function", c="red")

plt.title(str(N_max_5_Fourier) + "th harmonic of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
ReconstFunc_5_5, ReconstTime_5_5 = FourierCalcReal(a_0_5, a_5, b_5, t_5_Fourier, T_5_Fourier, 5)
ReconstFunc_5_10, ReconstTime_5_10 = FourierCalcReal(a_0_5, a_5, b_5, t_5_Fourier, T_5_Fourier, 10)
ReconstFunc_5_30, ReconstTime_5_30 = FourierCalcReal(a_0_5, a_5, b_5, t_5_Fourier, T_5_Fourier, 30)

# %%
fig_f_5_Reconstruct_Compare = plt.figure(figsize=(10,7))

plt.plot(time_5, signal_5, label="Original function")
plt.plot(ReconstTime_5_5, ReconstFunc_5_5, label="Reconstructed function (5 periods)")
plt.plot(ReconstTime_5_10, ReconstFunc_5_10, label="Reconstructed function (10 periods)")
plt.plot(ReconstTime_5_30, ReconstFunc_5_30, label="Reconstructed function (30 periods)")

plt.title("Comparing various harmonics of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# #### 6) $f(x) = pi^2 - x^2$, if $x \in [- \pi, \pi]$, with $T = 2 \pi$

# %%
def f_6(t):
    '''
    Input parameter:
    
    't': time in seconds
    '''
    
    T = 2 * np.pi
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):

        if(((t/SampRate * i) % T) <= T/2):
            signal[i] = np.pi**2 - ((t/SampRate * i) % T)**2
            i += 1
        else:
            signal[i] = np.pi**2 - (T - ((t/SampRate * i) % T))**2
            i += 1

    return(time, signal, T)

# %%
t_6_Fourier = 15

time_6, signal_6, T_6_Fourier = f_6(t_6_Fourier)

# %%
fig_f_6 = plt.figure(figsize=(10,7))

plt.plot(time_6, signal_6)

plt.title("f(x) = pi^2 - x^2 wave with " + str(T_6_Fourier) + "s period")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
def f_6_Fourier(N_max):
    
    '''
    Input parameters:
    
    'N_max': period of signal
    '''
    
    T = 2 * np.pi
    
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    f_sample = 2 * N_max
    
    # We also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    time = np.linspace(0, T, f_sample + 2, endpoint=False)
    
    # np.array for containting values of current function
    signal = np.empty(f_sample + 2)
    
    i = 0
    while(i < (f_sample + 2)):
        
        if((time[f_sample + 1]/(f_sample + 2) * i) % T <= T/2):
            signal[i] = np.pi**2 - ((time[f_sample + 1]/(f_sample + 2) * i) % T)**2
            i += 1
        else:
            signal[i] = np.pi**2 - (T - ((time[f_sample + 1]/(f_sample + 2) * i) % T))**2
            i += 1

    return(time, signal, T)

# %%
N_max_6_Fourier = 40

time_6_Fourier, signal_6_Fourier, T_6_Fourier = f_6_Fourier(N_max_6_Fourier)

# %% [markdown]
# #### Plot one period of the signal

# %%
fig_f_6_Period = plt.figure(figsize=(10,7))

plt.plot(time_6_Fourier, signal_6_Fourier)

plt.title("f(x) = pi^2 - x^2 wave with " + str(T_6_Fourier) + "s period\n(Only showing 1 period)")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
a_0_6, a_6, b_6 = FourierCoeff(signal_6_Fourier, time_6_Fourier, N_max_6_Fourier)

# %%
fig_f_6_CoefficientScatter = plt.figure(figsize=(10,7))

plt.scatter(0,a_0_6, label="a_0",c="blue")
plt.scatter(np.linspace(1,N_max_6_Fourier,N_max_6_Fourier), a_6, label="a_k",c="red")
plt.scatter(np.linspace(1,N_max_6_Fourier,N_max_6_Fourier), b_6, label="b_k",c="green")

plt.title("Coefficients of Fourier series")
plt.xlabel("Harmonics (k)")
plt.ylabel("Value of kth coefficient")

#plt.ylim(-0.01,0.01)

plt.legend()
plt.show()

# %%
ReconstFunc_6, ReconstTime_6 = FourierCalcReal(a_0_6, a_6, b_6, t_6_Fourier, T_6_Fourier, N_max_6_Fourier)

# %%
fig_f_6_Reconstruct = plt.figure(figsize=(10,7))

plt.plot(time_6, signal_6, label="Original function", c="green")
plt.plot(ReconstTime_6, ReconstFunc_6, label="Reconstructed function", c="red")

plt.title(str(N_max_6_Fourier) + "th harmonic of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
ReconstFunc_6_5, ReconstTime_6_5 = FourierCalcReal(a_0_6, a_6, b_6, t_6_Fourier, T_6_Fourier, 5)
ReconstFunc_6_10, ReconstTime_6_10 = FourierCalcReal(a_0_6, a_6, b_6, t_6_Fourier, T_6_Fourier, 10)
ReconstFunc_6_30, ReconstTime_6_30 = FourierCalcReal(a_0_6, a_6, b_6, t_6_Fourier, T_6_Fourier, 30)

# %%
fig_f_6_Reconstruct_Compare = plt.figure(figsize=(10,7))

plt.plot(time_6, signal_6, label="Original function")
plt.plot(ReconstTime_6_5, ReconstFunc_6_5, label="Reconstructed function (5 periods)")
plt.plot(ReconstTime_6_10, ReconstFunc_6_10, label="Reconstructed function (10 periods)")
plt.plot(ReconstTime_6_30, ReconstFunc_6_30, label="Reconstructed function (30 periods)")

plt.title("Comparing various harmonics of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# #### 7) $f(x) = (x-3)(x-1)$, if $x \in [1,3]$, with $T = 2$

# %%
def f_7(t):
    '''
    Input parameter:
    
    't': time in seconds
    '''
    
    T = 2
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):

        signal[i] = ((((t/SampRate * i) - 1) % T) - 3) * ((((t/SampRate * i) - 1) % T) - 1)
        i += 1

    return(time, signal, T)

# %%
t_7_Fourier = 4

time_7, signal_7, T_7_Fourier = f_7(t_7_Fourier)

# %%
fig_f_7 = plt.figure(figsize=(10,7))

plt.plot(time_7, signal_7)

plt.title("f(x) = (x-3)(x-1) wave with " + str(T_7_Fourier) + "s period")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
def f_7_Fourier(N_max):
    
    '''
    Input parameters:
    
    'N_max': period of signal
    '''
    
    T = 2
    
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    f_sample = 2 * N_max
    
    # We also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    time = np.linspace(0, T, f_sample + 2, endpoint=False)
    
    # np.array for containting values of current function
    signal = np.empty(f_sample + 2)
    
    i = 0
    while(i < (f_sample + 2)):
        
        signal[i] = ((((time[f_sample + 1]/(f_sample + 2) * i) - 1) % T) - 3) * ((((time[f_sample + 1]/(f_sample + 2) * i) - 1) % T) - 1)
        i += 1

    return(time, signal, T)

# %%
N_max_7_Fourier = 40

time_7_Fourier, signal_7_Fourier, T_7_Fourier = f_7_Fourier(N_max_7_Fourier)

# %% [markdown]
# #### Plot one period of the signal

# %%
fig_f_7_Period = plt.figure(figsize=(10,7))

plt.plot(time_7_Fourier, signal_7_Fourier)

plt.title("f(x) = (x-3)(x-1) wave with " + str(T_7_Fourier) + "s period\n(Only showing 1 period)")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
a_0_7, a_7, b_7 = FourierCoeff(signal_7_Fourier, time_7_Fourier, N_max_7_Fourier)

# %%
fig_f_7_CoefficientScatter = plt.figure(figsize=(10,7))

plt.scatter(0,a_0_7, label="a_0",c="blue")
plt.scatter(np.linspace(1,N_max_7_Fourier,N_max_7_Fourier), a_7, label="a_k",c="red")
plt.scatter(np.linspace(1,N_max_7_Fourier,N_max_7_Fourier), b_7, label="b_k",c="green")

plt.title("Coefficients of Fourier series")
plt.xlabel("Harmonics (k)")
plt.ylabel("Value of kth coefficient")

#plt.ylim(-0.01,0.01)

plt.legend()
plt.show()

# %%
ReconstFunc_7, ReconstTime_7 = FourierCalcReal(a_0_7, a_7, b_7, t_7_Fourier, T_7_Fourier, N_max_7_Fourier)

# %%
fig_f_7_Reconstruct = plt.figure(figsize=(10,7))

plt.plot(time_7, signal_7, label="Original function", c="green")
plt.plot(ReconstTime_7, ReconstFunc_7, label="Reconstructed function", c="red")

plt.title(str(N_max_7_Fourier) + "th harmonic of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
ReconstFunc_7_5, ReconstTime_7_5 = FourierCalcReal(a_0_7, a_7, b_7, t_7_Fourier, T_7_Fourier, 5)
ReconstFunc_7_10, ReconstTime_7_10 = FourierCalcReal(a_0_7, a_7, b_7, t_7_Fourier, T_7_Fourier, 10)
ReconstFunc_7_30, ReconstTime_7_30 = FourierCalcReal(a_0_7, a_7, b_7, t_7_Fourier, T_7_Fourier, 30)

# %%
fig_f_7_Reconstruct_Compare = plt.figure(figsize=(10,7))

plt.plot(time_7, signal_7, label="Original function")
plt.plot(ReconstTime_7_5, ReconstFunc_7_5, label="Reconstructed function (5 periods)")
plt.plot(ReconstTime_7_10, ReconstFunc_7_10, label="Reconstructed function (10 periods)")
plt.plot(ReconstTime_7_30, ReconstFunc_7_30, label="Reconstructed function (30 periods)")

plt.title("Comparing various harmonics of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# #### 8) $f(x) = x$, with $T = 1$

# %%
def f_8(t):
    '''
    Input parameter:
    
    't': time in seconds
    '''
    
    T = 1
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):

        signal[i] = (((t/SampRate * i) - 1) % T) 
        i += 1

    return(time, signal, T)

# %%
t_8_Fourier = 2

time_8, signal_8, T_8_Fourier = f_8(t_8_Fourier)

# %%
fig_f_8 = plt.figure(figsize=(10,7))

plt.plot(time_8, signal_8)

plt.title("f(x) = x wave with " + str(T_8_Fourier) + "s period")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
def f_8_Fourier(N_max):
    
    '''
    Input parameters:
    
    'N_max': period of signal
    '''
    
    T = 1
    
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    f_sample = 2 * N_max
    
    # We also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    time = np.linspace(0, T, f_sample + 2, endpoint=False)
    
    # np.array for containting values of current function
    signal = np.empty(f_sample + 2)
    
    i = 0
    while(i < (f_sample + 2)):
        
        signal[i] = ((time[f_sample + 1]/(f_sample + 2) * i) % T)
        i += 1

    return(time, signal, T)

# %%
N_max_8_Fourier = 40

time_8_Fourier, signal_8_Fourier, T_8_Fourier = f_8_Fourier(N_max_8_Fourier)

# %% [markdown]
# #### Plot one period of the signal

# %%
fig_f_8_Period = plt.figure(figsize=(10,7))

plt.plot(time_8_Fourier, signal_8_Fourier)

plt.title("f(x) = x wave with " + str(T_8_Fourier) + "s period\n(Only showing 1 period)")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
a_0_8, a_8, b_8 = FourierCoeff(signal_8_Fourier, time_8_Fourier, N_max_8_Fourier)

# %%
fig_f_8_CoefficientScatter = plt.figure(figsize=(10,7))

plt.scatter(0,a_0_8, label="a_0",c="blue")
plt.scatter(np.linspace(1,N_max_8_Fourier,N_max_8_Fourier), a_8, label="a_k",c="red")
plt.scatter(np.linspace(1,N_max_8_Fourier,N_max_8_Fourier), b_8, label="b_k",c="green")

plt.title("Coefficients of Fourier series")
plt.xlabel("Harmonics (k)")
plt.ylabel("Value of kth coefficient")

#plt.ylim(-0.01,0.01)

plt.legend()
plt.show()

# %%
ReconstFunc_8, ReconstTime_8 = FourierCalcReal(a_0_8, a_8, b_8, t_8_Fourier, T_8_Fourier, N_max_8_Fourier)

# %%
fig_f_8_Reconstruct = plt.figure(figsize=(10,7))

plt.plot(time_8, signal_8, label="Original function", c="green")
plt.plot(ReconstTime_8, ReconstFunc_8, label="Reconstructed function", c="red")

plt.title(str(N_max_8_Fourier) + "th harmonic of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
ReconstFunc_8_5, ReconstTime_8_5 = FourierCalcReal(a_0_8, a_8, b_8, t_8_Fourier, T_8_Fourier, 5)
ReconstFunc_8_10, ReconstTime_8_10 = FourierCalcReal(a_0_8, a_8, b_8, t_8_Fourier, T_8_Fourier, 10)
ReconstFunc_8_30, ReconstTime_8_30 = FourierCalcReal(a_0_8, a_8, b_8, t_8_Fourier, T_8_Fourier, 30)

# %%
fig_f_8_Reconstruct_Compare = plt.figure(figsize=(10,7))

plt.plot(time_8, signal_8, label="Original function")
plt.plot(ReconstTime_8_5, ReconstFunc_8_5, label="Reconstructed function (5 periods)")
plt.plot(ReconstTime_8_10, ReconstFunc_8_10, label="Reconstructed function (10 periods)")
plt.plot(ReconstTime_8_30, ReconstFunc_8_30, label="Reconstructed function (30 periods)")

plt.title("Comparing various harmonics of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# #### 9) $f(x) = 0$, if $x \in [- \pi,0]$ and $f(x) = 1$, if $x \in [0, \pi]$

# %%
def f_9(t):
    '''
    Input parameter:
    
    't': time in seconds
    '''
    
    T = 2 * np.pi
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):

        if((t/SampRate * i) % T <= T/2):
            signal[i] = 1
            i += 1
        else:
            signal[i] = 0
            i += 1

    return(time, signal, T)

# %%
t_9_Fourier = 15

time_9, signal_9, T_9_Fourier = f_9(t_9_Fourier)

# %%
fig_f_9 = plt.figure(figsize=(10,7))

plt.plot(time_9, signal_9)

plt.title("f(x) = 0 if x e [-pi,0] and 1 if x e [0,pi] wave with " + str(T_9_Fourier) + "s period")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
def f_9_Fourier(N_max):
    
    '''
    Input parameters:
    
    'N_max': period of signal
    '''
    
    T = 2 * np.pi
    
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    f_sample = 2 * N_max
    
    # We also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    time = np.linspace(0, T, f_sample + 2, endpoint=False)
    
    # np.array for containting values of current function
    signal = np.empty(f_sample + 2)
    
    i = 0
    while(i < (f_sample + 2)):
        
        if((time[f_sample + 1]/(f_sample + 2) * i) % T <= T/2):
            signal[i] = 1
            i += 1
        else:
            signal[i] = 0
            i += 1

    return(time, signal, T)

# %%
N_max_9_Fourier = 40

time_9_Fourier, signal_9_Fourier, T_9_Fourier = f_9_Fourier(N_max_9_Fourier)

# %% [markdown]
# #### Plot one period of the signal

# %%
fig_f_9_Period = plt.figure(figsize=(10,7))

plt.plot(time_9_Fourier, signal_9_Fourier)

plt.title("f(x) = 0 if x e [-pi,0] and 1 if x e [0,pi] wave with " + str(T_9_Fourier) + "s period\n(Only showing 1 period)")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
a_0_9, a_9, b_9 = FourierCoeff(signal_9_Fourier, time_9_Fourier, N_max_9_Fourier)

# %%
fig_f_9_CoefficientScatter = plt.figure(figsize=(10,7))

plt.scatter(0,a_0_9, label="a_0",c="blue")
plt.scatter(np.linspace(1,N_max_9_Fourier,N_max_9_Fourier), a_9, label="a_k",c="red")
plt.scatter(np.linspace(1,N_max_9_Fourier,N_max_9_Fourier), b_9, label="b_k",c="green")

plt.title("Coefficients of Fourier series")
plt.xlabel("Harmonics (k)")
plt.ylabel("Value of kth coefficient")

#plt.ylim(-0.01,0.01)

plt.legend()
plt.show()

# %%
ReconstFunc_9, ReconstTime_9 = FourierCalcReal(a_0_9, a_9, b_9, t_9_Fourier, T_9_Fourier, N_max_9_Fourier)

# %%
fig_f_9_Reconstruct = plt.figure(figsize=(10,7))

plt.plot(time_9, signal_9, label="Original function", c="green")
plt.plot(ReconstTime_9, ReconstFunc_9, label="Reconstructed function", c="red")

plt.title(str(N_max_9_Fourier) + "th harmonic of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
ReconstFunc_9_5, ReconstTime_9_5 = FourierCalcReal(a_0_9, a_9, b_9, t_9_Fourier, T_9_Fourier, 5)
ReconstFunc_9_10, ReconstTime_9_10 = FourierCalcReal(a_0_9, a_9, b_9, t_9_Fourier, T_9_Fourier, 10)
ReconstFunc_9_30, ReconstTime_9_30 = FourierCalcReal(a_0_9, a_9, b_9, t_9_Fourier, T_9_Fourier, 30)

# %%
fig_f_9_Reconstruct_Compare = plt.figure(figsize=(10,7))

plt.plot(time_9, signal_9, label="Original function")
plt.plot(ReconstTime_9_5, ReconstFunc_9_5, label="Reconstructed function (5 periods)")
plt.plot(ReconstTime_9_10, ReconstFunc_9_10, label="Reconstructed function (10 periods)")
plt.plot(ReconstTime_9_30, ReconstFunc_9_30, label="Reconstructed function (30 periods)")

plt.title("Comparing various harmonics of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# #### 10) $f(x) = −1$, if $x \in [−3,0]$ and $f(x) = 1$, if $x \in [0,3]$.

# %%
def f_10(t):
    '''
    Input parameter:
    
    't': time in seconds
    '''
    
    T = 6
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):

        if((t/SampRate * i) % T <= T/2):
            signal[i] = 1
            i += 1
        else:
            signal[i] = -1
            i += 1

    return(time, signal, T)

# %%
t_10_Fourier = 15

time_10, signal_10, T_10_Fourier = f_10(t_10_Fourier)

# %%
fig_f_10 = plt.figure(figsize=(10,7))

plt.plot(time_10, signal_10)

plt.title("f(x) = -1 if x e [-3,0] and 1 if x e [0,3] wave with " + str(T_10_Fourier) + "s period")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
def f_10_Fourier(N_max):
    
    '''
    Input parameters:
    
    'N_max': period of signal
    '''
    
    T = 6
    
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    f_sample = 2 * N_max
    
    # We also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    time = np.linspace(0, T, f_sample + 2, endpoint=False)
    
    # np.array for containting values of current function
    signal = np.empty(f_sample + 2)
    
    i = 0
    while(i < (f_sample + 2)):
        
        if((time[f_sample + 1]/(f_sample + 2) * i) % T <= T/2):
            signal[i] = 1
            i += 1
        else:
            signal[i] = -1
            i += 1

    return(time, signal, T)

# %%
N_max_10_Fourier = 40

time_10_Fourier, signal_10_Fourier, T_10_Fourier = f_10_Fourier(N_max_10_Fourier)

# %% [markdown]
# #### Plot one period of the signal

# %%
fig_f_10_Period = plt.figure(figsize=(10,7))

plt.plot(time_10_Fourier, signal_10_Fourier)

plt.title("f(x) = -1 if x e [-3,0] and 1 if x e [0,3] wave with " + str(T_10_Fourier) + "s period\n(Only showing 1 period)")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
a_0_10, a_10, b_10 = FourierCoeff(signal_10_Fourier, time_10_Fourier, N_max_10_Fourier)

# %%
fig_f_10_CoefficientScatter = plt.figure(figsize=(10,7))

plt.scatter(0,a_0_10, label="a_0",c="blue")
plt.scatter(np.linspace(1,N_max_10_Fourier,N_max_10_Fourier), a_10, label="a_k",c="red")
plt.scatter(np.linspace(1,N_max_10_Fourier,N_max_10_Fourier), b_10, label="b_k",c="green")

plt.title("Coefficients of Fourier series")
plt.xlabel("Harmonics (k)")
plt.ylabel("Value of kth coefficient")

#plt.ylim(-0.01,0.01)

plt.legend()
plt.show()

# %%
ReconstFunc_10, ReconstTime_10 = FourierCalcReal(a_0_10, a_10, b_10, t_10_Fourier, T_10_Fourier, N_max_10_Fourier)

# %%
fig_f_10_Reconstruct = plt.figure(figsize=(10,7))

plt.plot(time_10, signal_10, label="Original function", c="green")
plt.plot(ReconstTime_10, ReconstFunc_10, label="Reconstructed function", c="red")

plt.title(str(N_max_10_Fourier) + "th harmonic of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
ReconstFunc_10_5, ReconstTime_10_5 = FourierCalcReal(a_0_10, a_10, b_10, t_10_Fourier, T_10_Fourier, 5)
ReconstFunc_10_10, ReconstTime_10_10 = FourierCalcReal(a_0_10, a_10, b_10, t_10_Fourier, T_10_Fourier, 10)
ReconstFunc_10_30, ReconstTime_10_30 = FourierCalcReal(a_0_10, a_10, b_10, t_10_Fourier, T_10_Fourier, 30)

# %%
fig_f_10_Reconstruct_Compare = plt.figure(figsize=(10,7))

plt.plot(time_10, signal_10, label="Original function")
plt.plot(ReconstTime_10_5, ReconstFunc_10_5, label="Reconstructed function (5 periods)")
plt.plot(ReconstTime_10_10, ReconstFunc_10_10, label="Reconstructed function (10 periods)")
plt.plot(ReconstTime_10_30, ReconstFunc_10_30, label="Reconstructed function (30 periods)")

plt.title("Comparing various harmonics of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# #### 11) $f(x) = 1$, if $x \in [−1,0]$, and $f(x) = 1/2$, if $x = 0$, and $f(x) = x$, if $x \in [0,1]$

# %%
def f_11(t):
    '''
    Input parameter:
    
    't': time in seconds
    '''
    
    T = 2
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):

        if((t/SampRate * i) % T < T/2):
            signal[i] = 1
            i += 1
        
        elif((t/SampRate * i) % T == T/2):
            signal[i] = 1/2
            i += 1
        
        else:
            signal[i] = 0
            i += 1

    return(time, signal, T)

# %%
t_11_Fourier = 2

time_11, signal_11, T_11_Fourier = f_11(t_11_Fourier)

# %%
fig_f_11 = plt.figure(figsize=(10,7))

plt.scatter(time_11, signal_11)
plt.plot(time_11, signal_11, c="red")

plt.title("f(x)_11th wave with " + str(T_11_Fourier) + "s period")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
def f_11_Fourier(N_max):
    
    '''
    Input parameters:
    
    'N_max': period of signal
    '''
    
    T = 2
    
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    f_sample = 2 * N_max
    
    # We also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    time = np.linspace(0, T, f_sample + 2, endpoint=False)
    
    # np.array for containting values of current function
    signal = np.empty(f_sample + 2)
    
    i = 0
    while(i < (f_sample + 2)):
        
        if((time[f_sample + 1]/(f_sample + 2) * i) % T < T/2):
            signal[i] = 1
            i += 1
        
        elif((time[f_sample + 1]/(f_sample + 2) * i) % T == T/2):
            signal[i] = 1/2
            i += 1
        
        else:
            signal[i] = 0
            i += 1

    return(time, signal, T)

# %%
N_max_11_Fourier = 40

time_11_Fourier, signal_11_Fourier, T_11_Fourier = f_11_Fourier(N_max_11_Fourier)

# %% [markdown]
# #### Plot one period of the signal

# %%
fig_f_11_Period = plt.figure(figsize=(10,7))

plt.scatter(time_11_Fourier, signal_11_Fourier)
plt.plot(time_11_Fourier, signal_11_Fourier, c="red")

plt.title("f(x)_11th wave with " + str(T_11_Fourier) + "s period\n(Only showing 1 period)")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
a_0_11, a_11, b_11 = FourierCoeff(signal_11_Fourier, time_11_Fourier, N_max_11_Fourier)

# %%
fig_f_11_CoefficientScatter = plt.figure(figsize=(10,7))

plt.scatter(0,a_0_11, label="a_0",c="blue", marker='.')
plt.scatter(np.linspace(1,N_max_11_Fourier,N_max_11_Fourier), a_11, label="a_k",c="red")
plt.scatter(np.linspace(1,N_max_11_Fourier,N_max_11_Fourier), b_11, label="b_k",c="green")

plt.title("Coefficients of Fourier series")
plt.xlabel("Harmonics (k)")
plt.ylabel("Value of kth coefficient")

#plt.ylim(-0.01,0.01)

plt.legend()
plt.show()

# %%
ReconstFunc_11, ReconstTime_11 = FourierCalcReal(a_0_11, a_11, b_11, t_11_Fourier, T_11_Fourier, N_max_11_Fourier)

# %%
fig_f_11_Reconstruct = plt.figure(figsize=(10,7))

plt.scatter(time_11, signal_11, label="Original function (scatter plot)", c="green")
plt.plot(ReconstTime_11, ReconstFunc_11, label="Reconstructed function", c="red")

plt.title(str(N_max_11_Fourier) + "th harmonic of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
ReconstFunc_11_5, ReconstTime_11_5 = FourierCalcReal(a_0_11, a_11, b_11, t_11_Fourier, T_11_Fourier, 5)
ReconstFunc_11_10, ReconstTime_11_10 = FourierCalcReal(a_0_11, a_11, b_11, t_11_Fourier, T_11_Fourier, 10)
ReconstFunc_11_30, ReconstTime_11_30 = FourierCalcReal(a_0_11, a_11, b_11, t_11_Fourier, T_11_Fourier, 30)

# %%
fig_f_11_Reconstruct_Compare = plt.figure(figsize=(10,7))

plt.scatter(time_11, signal_11, label="Original function (scatter plot)")
plt.plot(ReconstTime_11_5, ReconstFunc_11_5, label="Reconstructed function (5 periods)",c="red")
plt.plot(ReconstTime_11_10, ReconstFunc_11_10, label="Reconstructed function (10 periods)",c="green")
plt.plot(ReconstTime_11_30, ReconstFunc_11_30, label="Reconstructed function (30 periods)",c="orange")

plt.title("Comparing various harmonics of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# #### 12) $f(x) = 0$, if $x \in [−2,0]$, and $f(x) = x$, if $x \in [0,2]$

# %%
def f_12(t):
    '''
    Input parameter:
    
    't': time in seconds
    '''
    
    T = 4
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)
    
    i = 0
    while(i < SampRate):

        if((t/SampRate * i) % T <= T/2):
            signal[i] = (t/SampRate * i) % T
            i += 1
        
        else:
            signal[i] = 0
            i += 1

    return(time, signal, T)

# %%
t_12_Fourier = 6

time_12, signal_12, T_12_Fourier = f_12(t_12_Fourier)

# %%
fig_f_12 = plt.figure(figsize=(10,7))

plt.scatter(time_12, signal_12)
plt.plot(time_12, signal_12, c="red")

plt.title("f(x)_12th wave with " + str(T_12_Fourier) + "s period")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
def f_12_Fourier(N_max):
    
    '''
    Input parameters:
    
    'N_max': period of signal
    '''
    
    T = 4
    
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    f_sample = 2 * N_max
    
    # We also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    time = np.linspace(0, T, f_sample + 2, endpoint=False)
    
    # np.array for containting values of current function
    signal = np.empty(f_sample + 2)
    
    i = 0
    while(i < (f_sample + 2)):
        
        if((time[f_sample + 1]/(f_sample + 2) * i) % T <= T/2):
            signal[i] = (time[f_sample + 1]/(f_sample + 2) * i) % T
            i += 1
        
        else:
            signal[i] = 0
            i += 1

    return(time, signal, T)

# %%
N_max_12_Fourier = 40

time_12_Fourier, signal_12_Fourier, T_12_Fourier = f_12_Fourier(N_max_12_Fourier)

# %% [markdown]
# #### Plot one period of the signal

# %%
fig_f_12_Period = plt.figure(figsize=(10,7))

plt.scatter(time_12_Fourier, signal_12_Fourier)
plt.plot(time_12_Fourier, signal_12_Fourier, c="red")

plt.title("f(x)_12th wave with " + str(T_12_Fourier) + "s period\n(Only showing 1 period)")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
a_0_12, a_12, b_12 = FourierCoeff(signal_12_Fourier, time_12_Fourier, N_max_12_Fourier)

# %%
fig_f_12_CoefficientScatter = plt.figure(figsize=(10,7))

plt.scatter(0,a_0_12, label="a_0",c="blue")
plt.scatter(np.linspace(1,N_max_12_Fourier,N_max_12_Fourier), a_12, label="a_k",c="red")
plt.scatter(np.linspace(1,N_max_12_Fourier,N_max_12_Fourier), b_12, label="b_k",c="green")

plt.title("Coefficients of Fourier series")
plt.xlabel("Harmonics (k)")
plt.ylabel("Value of kth coefficient")

#plt.ylim(-0.01,0.01)

plt.legend()
plt.show()

# %%
ReconstFunc_12, ReconstTime_12 = FourierCalcReal(a_0_12, a_12, b_12, t_12_Fourier, T_12_Fourier, N_max_12_Fourier)

# %%
fig_f_12_Reconstruct = plt.figure(figsize=(10,7))

plt.scatter(time_12, signal_12, label="Original function (scatter plot)", c="green", marker='.')
plt.plot(ReconstTime_12, ReconstFunc_12, label="Reconstructed function", c="red")

plt.title(str(N_max_12_Fourier) + "th harmonic of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
ReconstFunc_12_5, ReconstTime_12_5 = FourierCalcReal(a_0_12, a_12, b_12, t_12_Fourier, T_12_Fourier, 5)
ReconstFunc_12_10, ReconstTime_12_10 = FourierCalcReal(a_0_12, a_12, b_12, t_12_Fourier, T_12_Fourier, 10)
ReconstFunc_12_30, ReconstTime_12_30 = FourierCalcReal(a_0_12, a_12, b_12, t_12_Fourier, T_12_Fourier, 30)

# %%
fig_f_12_Reconstruct_Compare = plt.figure(figsize=(10,7))

plt.scatter(time_12, signal_12, label="Original function (scatter plot)", marker='.')
plt.plot(ReconstTime_12_5, ReconstFunc_12_5, label="Reconstructed function (5 periods)",c="red")
plt.plot(ReconstTime_12_10, ReconstFunc_12_10, label="Reconstructed function (10 periods)",c="green")
plt.plot(ReconstTime_12_30, ReconstFunc_12_30, label="Reconstructed function (30 periods)",c="orange")

plt.title("Comparing various harmonics of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# #### 13) $f(x) = \sin \left( \tfrac{2 \pi t}{T} \right)$, if $x \in [0,T/2]$, and $f(x) = 0$, if $x \in [T/2,T]$

# %%
def f_13(t, T):
    '''
    Input parameter:
    
    't': time in seconds
    '''
    
    # Sampling rate: 1000 Hz/second
    SampRate = t * 1000
    time = np.linspace(0, t, SampRate, endpoint=True)
    
    # np.array for containting values of current function
    signal = np.empty(SampRate)

    i = 0
    while(i < SampRate):

        if((t/SampRate * i) % T <= T/2):
            signal[i] = np.sin(2 * np.pi * (t/SampRate * i) / T)
            i += 1

        else:
            signal[i] = 0
            i += 1

    return(time, signal, T)

# %%
t_13_Fourier = 6
T_13_Fourier = np.pi

time_13, signal_13, T_13_Fourier = f_13(t_13_Fourier, T_13_Fourier)

# %%
fig_f_13 = plt.figure(figsize=(10,7))

plt.scatter(time_13, signal_13)
plt.plot(time_13, signal_13, c="red")

plt.title("f(x)_13th wave with " + str(T_13_Fourier) + "s period")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
def f_13_Fourier(T, N_max):
    
    '''
    Input parameters:
    
    'N_max': period of signal
    '''
    
    # From Shanon theoreom we must use a sampling frequency larger than the maximum
    # frequency you want to catch in the signal
    f_sample = 2 * N_max
    
    # We also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    time = np.linspace(0, T, f_sample + 2, endpoint=False)
    
    # np.array for containting values of current function
    signal = np.empty(f_sample + 2)
    
    i = 0
    while(i < (f_sample + 2)):
        
        if((time[f_sample + 1]/(f_sample + 2) * i) % T <= T/2):
            signal[i] = np.sin(2 * np.pi * (time[f_sample + 1]/(f_sample + 2) * i) / T)
            i += 1
        
        else:
            signal[i] = 0
            i += 1

    return(time, signal, T)

# %%
N_max_13_Fourier = 40

time_13_Fourier, signal_13_Fourier, T_13_Fourier = f_13_Fourier(T_13_Fourier, N_max_13_Fourier)

# %% [markdown]
# #### Plot one period of the signal

# %%
fig_f_13_Period = plt.figure(figsize=(10,7))

plt.scatter(time_13_Fourier, signal_13_Fourier)
plt.plot(time_13_Fourier, signal_13_Fourier, c="red")

plt.title("f(x)_13th wave with " + str(T_13_Fourier) + "s period\n(Only showing 1 period)")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt. show()

# %%
a_0_13, a_13, b_13 = FourierCoeff(signal_13_Fourier, time_13_Fourier, N_max_13_Fourier)

# %%
fig_f_13_CoefficientScatter = plt.figure(figsize=(10,7))

plt.scatter(0,a_0_13, label="a_0",c="blue")
plt.scatter(np.linspace(1,N_max_13_Fourier,N_max_13_Fourier), a_13, label="a_k",c="red")
plt.scatter(np.linspace(1,N_max_13_Fourier,N_max_13_Fourier), b_13, label="b_k",c="green")

plt.title("Coefficients of Fourier series")
plt.xlabel("Harmonics (k)")
plt.ylabel("Value of kth coefficient")

#plt.ylim(-0.01,0.01)

plt.legend()
plt.show()

# %%
ReconstFunc_13, ReconstTime_13 = FourierCalcReal(a_0_13, a_13, b_13, t_13_Fourier, T_13_Fourier, N_max_13_Fourier)

# %%
fig_f_13_Reconstruct = plt.figure(figsize=(10,7))

plt.scatter(time_13, signal_13, label="Original function (scatter plot)", c="green", marker='.')
plt.plot(ReconstTime_13, ReconstFunc_13, label="Reconstructed function", c="red")

plt.title(str(N_max_13_Fourier) + "th harmonic of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %%
ReconstFunc_13_5, ReconstTime_13_5 = FourierCalcReal(a_0_13, a_13, b_13, t_13_Fourier, T_13_Fourier, 5)
ReconstFunc_13_10, ReconstTime_13_10 = FourierCalcReal(a_0_13, a_13, b_13, t_13_Fourier, T_13_Fourier, 10)
ReconstFunc_13_30, ReconstTime_13_30 = FourierCalcReal(a_0_13, a_13, b_13, t_13_Fourier, T_13_Fourier, 30)

# %%
fig_f_13_Reconstruct_Compare = plt.figure(figsize=(10,7))

plt.scatter(time_13, signal_13, label="Original function (scatter plot)", marker='.')
plt.plot(ReconstTime_13_5, ReconstFunc_13_5, label="Reconstructed function (5 periods)",c="red")
plt.plot(ReconstTime_13_10, ReconstFunc_13_10, label="Reconstructed function (10 periods)",c="green")
plt.plot(ReconstTime_13_30, ReconstFunc_13_30, label="Reconstructed function (30 periods)",c="orange")

plt.title("Comparing various harmonics of Fourier series")
plt.xlabel("Time (s)")
plt.ylabel("Signal value")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# ## Task 4
